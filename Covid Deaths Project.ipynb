# %% [markdown]
# # Utilizing a comprehensive COVID-19 dataset spanning from 2020 to 2023, Multiple Linear Regression (MLR) algorithm is employed to construct a predictive model for death, considering a multitude of variables.

# %% [markdown]
# # DATA WRANGLING PROCESS

# %%
import numpy as np
import pandas as pd
#import pandas_profiling as pp
import ydata_profiling as pp
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn
from sklearn import linear_model
from sklearn.metrics import mean_squared_error
# %matplotlib inline 
#to execute method in library although version not updated

# %%
CovidDeaths = pd.read_csv('CovidDeaths.csv')
CovidDeaths.describe()
# Out:
# C:\Users\dausy\AppData\Local\Temp\ipykernel_20160\3021864066.py:1: DtypeWarning: Columns (6) have mixed types. Specify dtype option on import or set low_memory=False.
#   CovidDeaths = pd.read_csv('CovidDeaths.csv')
#          population   total_cases  new_cases_smoothed  total_deaths
# count  3.080070e+05  2.719050e+05        2.979340e+05  2.513450e+05  \
# mean   1.283649e+08  5.673000e+06        1.088439e+04  8.006052e+04
# std    6.605217e+08  3.547996e+07        1.008186e+05  4.139807e+05
# min    4.700000e+01  1.000000e+00        0.000000e+00  1.000000e+00
# 25%    4.490020e+05  6.444000e+03        1.143000e+00  1.200000e+02
# 50%    5.882259e+06  6.174500e+04        3.871400e+01  1.218000e+03
# 75%    2.830170e+07  6.331670e+05        6.394290e+02  1.050400e+04
# max    7.975105e+09  7.652222e+08        6.410719e+06  6.921601e+06
#
#           new_deaths  new_deaths_smoothed  total_cases_per_million
# count  299296.000000        298066.000000            271905.000000  \
# mean       96.684450            97.062506             86607.845076
# std       603.883003           594.584136            136982.850880
# min         0.000000             0.000000                 0.000000
# 25%         0.000000             0.000000              1991.558000
# 50%         0.000000             0.286000             20332.474000
# 75%         6.000000             6.714000            105419.525000
# max     20042.000000         14675.571000            734871.491000
#
#        new_cases_per_million  new_cases_smoothed_per_million
# count          299198.000000                   297934.000000  \
# mean              163.357032                      164.021170
# std              1131.843555                      637.665695
# min                 0.000000                        0.000000
# 25%                 0.000000                        0.263000
# 50%                 2.517000                       10.966000
# 75%                70.270500                      105.365000
# max            228872.025000                    37241.781000
#
#        total_deaths_per_million  ...  new_deaths_smoothed_per_million
# count             251345.000000  ...                    298066.000000  \
# mean                 804.720451  ...                         1.029812
# std                 1048.822115  ...                         2.928386
# min                    0.000000  ...                         0.000000
# 25%                   48.978000  ...                         0.000000
# 50%                  333.485000  ...                         0.034000
# 75%                 1236.212000  ...                         0.770000
# max                 6464.748000  ...                       148.641000
#
#        reproduction_rate  icu_patients  icu_patients_per_million
# count      184817.000000  35824.000000              35824.000000  \
# mean            0.911495    703.719043                 17.014529
# std             0.399925   2224.458299                 23.372177
# min            -0.070000      0.000000                  0.000000
# 25%             0.720000     24.000000                  2.933000
# 50%             0.950000    105.000000                  7.629000
# 75%             1.140000    460.000000                 21.441000
# max             5.870000  28891.000000                180.675000
#
#        hosp_patients  hosp_patients_per_million  weekly_icu_admissions
# count   36597.000000               36597.000000            9380.000000  \
# mean     4099.607454                 139.884563             366.984542
# std     10257.847760                 157.095870             541.479589
# min         0.000000                   0.000000               0.000000
# 25%       230.000000                  37.267000              28.000000
# 50%       807.000000                  87.633000             132.000000
# 75%      3171.000000                 183.723000             477.000000
# max    154497.000000                1526.846000            4838.000000
#
#        weekly_icu_admissions_per_million  weekly_hosp_admissions
# count                        9380.000000            21743.000000  \
# mean                           11.116090             4514.205859
# std                            14.142833            11380.778503
# min                             0.000000                0.000000
# 25%                             2.416250              280.000000
# 50%                             5.921000              939.000000
# 75%                            14.395500             4246.500000
# max                           224.976000           153977.000000
#
#        weekly_hosp_admissions_per_million
# count                        21743.000000
# mean                            91.622239
# std                             90.856741
# min                              0.000000
# 25%                             29.313000
# 50%                             66.670000
# 75%                            123.608500
# max                            708.310000
#
# [8 rows x 21 columns]

# %%
CovidDeaths.tail()
# Out:
#        iso_code continent  location       date  population  total_cases
# 308002      ZWE    Africa  Zimbabwe  29/4/2023    16320539     264679.0  \
# 308003      ZWE    Africa  Zimbabwe  30/4/2023    16320539     264683.0
# 308004      ZWE    Africa  Zimbabwe   1/5/2023    16320539     264685.0
# 308005      ZWE    Africa  Zimbabwe   2/5/2023    16320539     264685.0
# 308006      ZWE    Africa  Zimbabwe   3/5/2023    16320539     264685.0
#
#        new_cases  new_cases_smoothed  total_deaths  new_deaths  ...
# 308002      16.0               6.714        5685.0         0.0  ...  \
# 308003       4.0               6.571        5686.0         1.0  ...
# 308004       2.0               6.571        5686.0         0.0  ...
# 308005       0.0               6.000        5686.0         0.0  ...
# 308006       0.0               5.857        5686.0         0.0  ...
#
#         new_deaths_smoothed_per_million  reproduction_rate  icu_patients
# 308002                            0.000                NaN           NaN  \
# 308003                            0.009                NaN           NaN
# 308004                            0.009                NaN           NaN
# 308005                            0.009                NaN           NaN
# 308006                            0.009                NaN           NaN
#
#         icu_patients_per_million  hosp_patients  hosp_patients_per_million
# 308002                       NaN            NaN                        NaN  \
# 308003                       NaN            NaN                        NaN
# 308004                       NaN            NaN                        NaN
# 308005                       NaN            NaN                        NaN
# 308006                       NaN            NaN                        NaN
#
#         weekly_icu_admissions  weekly_icu_admissions_per_million
# 308002                    NaN                                NaN  \
# 308003                    NaN                                NaN
# 308004                    NaN                                NaN
# 308005                    NaN                                NaN
# 308006                    NaN                                NaN
#
#         weekly_hosp_admissions  weekly_hosp_admissions_per_million
# 308002                     NaN                                 NaN
# 308003                     NaN                                 NaN
# 308004                     NaN                                 NaN
# 308005                     NaN                                 NaN
# 308006                     NaN                                 NaN
#
# [5 rows x 26 columns]

# %% [markdown]
# # Filtering dataframe into Malaysian Country only

# %%
CovidDeaths = CovidDeaths[(CovidDeaths['location']=='Malaysia')] 
CovidDeaths
# Out:
#        iso_code continent  location      date  population  total_cases
# 161452      MYS      Asia  Malaysia  3/1/2020    33938216          NaN  \
# 161453      MYS      Asia  Malaysia  4/1/2020    33938216          NaN
# 161454      MYS      Asia  Malaysia  5/1/2020    33938216          NaN
# 161455      MYS      Asia  Malaysia  6/1/2020    33938216          NaN
# 161456      MYS      Asia  Malaysia  7/1/2020    33938216          NaN
# ...         ...       ...       ...       ...         ...          ...
# 162669      MYS      Asia  Malaysia  4/5/2023    33938216          NaN
# 162670      MYS      Asia  Malaysia  5/5/2023    33938216          NaN
# 162671      MYS      Asia  Malaysia  6/5/2023    33938216          NaN
# 162672      MYS      Asia  Malaysia  7/5/2023    33938216          NaN
# 162673      MYS      Asia  Malaysia  8/5/2023    33938216          NaN
#
#        new_cases  new_cases_smoothed  total_deaths  new_deaths  ...
# 161452       0.0                 NaN           NaN         0.0  ...  \
# 161453       0.0                 NaN           NaN         0.0  ...
# 161454       0.0                 NaN           NaN         0.0  ...
# 161455       0.0                 NaN           NaN         0.0  ...
# 161456       0.0                 NaN           NaN         0.0  ...
# ...          ...                 ...           ...         ...  ...
# 162669       NaN                 NaN           NaN         NaN  ...
# 162670       NaN                 NaN           NaN         NaN  ...
# 162671       NaN                 NaN           NaN         NaN  ...
# 162672       NaN                 NaN           NaN         NaN  ...
# 162673       NaN                 NaN           NaN         NaN  ...
#
#         new_deaths_smoothed_per_million  reproduction_rate  icu_patients
# 161452                              NaN                NaN           NaN  \
# 161453                              NaN                NaN           NaN
# 161454                              NaN                NaN           NaN
# 161455                              NaN                NaN           NaN
# 161456                              NaN                NaN           NaN
# ...                                 ...                ...           ...
# 162669                              NaN                NaN          43.0
# 162670                              NaN                NaN          44.0
# 162671                              NaN                NaN          41.0
# 162672                              NaN                NaN           NaN
# 162673                              NaN                NaN           NaN
#
#         icu_patients_per_million  hosp_patients  hosp_patients_per_million
# 161452                       NaN            NaN                        NaN  \
# 161453                       NaN            NaN                        NaN
# 161454                       NaN            NaN                        NaN
# 161455                       NaN            NaN                        NaN
# 161456                       NaN            NaN                        NaN
# ...                          ...            ...                        ...
# 162669                     1.267          774.0                     22.806
# 162670                     1.296          762.0                     22.453
# 162671                     1.208          766.0                     22.570
# 162672                       NaN            NaN                        NaN
# 162673                       NaN            NaN                        NaN
#
#         weekly_icu_admissions  weekly_icu_admissions_per_million
# 161452                    NaN                                NaN  \
# 161453                    NaN                                NaN
# 161454                    NaN                                NaN
# 161455                    NaN                                NaN
# 161456                    NaN                                NaN
# ...                       ...                                ...
# 162669                    NaN                                NaN
# 162670                    NaN                                NaN
# 162671                    NaN                                NaN
# 162672                    NaN                                NaN
# 162673                    NaN                                NaN
#
#         weekly_hosp_admissions  weekly_hosp_admissions_per_million
# 161452                     NaN                                 NaN
# 161453                     NaN                                 NaN
# 161454                     NaN                                 NaN
# 161455                     NaN                                 NaN
# 161456                     NaN                                 NaN
# ...                        ...                                 ...
# 162669                  1665.0                              49.060
# 162670                  1658.0                              48.853
# 162671                  1672.0                              49.266
# 162672                     NaN                                 NaN
# 162673                     NaN                                 NaN
#
# [1222 rows x 26 columns]

# %%
CovidDeaths.describe()
# Out:
#        population   total_cases  new_cases_smoothed  total_deaths
# count      1222.0  1.194000e+03         1210.000000   1143.000000  \
# mean   33938216.0  2.221174e+06         4188.656336  19028.132108
# std           0.0  2.083661e+06         6308.124403  16503.566664
# min    33938216.0  4.000000e+00            0.000000      2.000000
# 25%    33938216.0  5.071250e+04          213.142750    451.500000
# 50%    33938216.0  2.003606e+06         1905.500000  27265.000000
# 75%    33938216.0  4.592010e+06         4460.857250  35888.000000
# max    33938216.0  5.071840e+06        30729.857000  37020.000000
#
#         new_deaths  new_deaths_smoothed  total_cases_per_million
# count  1217.000000          1212.000000              1194.000000  \
# mean     30.419063            30.541380             65447.586225
# std      68.439252            66.375743             61395.722133
# min       0.000000             0.000000                 0.118000
# 25%       0.000000             1.143000              1494.259500
# 50%       5.000000             4.857000             59036.854000
# 75%      19.000000            19.643250            135304.997750
# max     592.000000           416.571000            149443.330000
#
#        new_cases_per_million  new_cases_smoothed_per_million
# count            1215.000000                     1210.000000  \
# mean              122.998619                      123.420048
# std               187.660830                      185.870829
# min                 0.000000                        0.000000
# 25%                 4.464000                        6.280250
# 50%                55.660000                       56.146000
# 75%               138.663500                      131.440750
# max               984.318000                      905.465000
#
#        total_deaths_per_million  ...  new_deaths_smoothed_per_million
# count               1143.000000  ...                      1212.000000  \
# mean                 560.669788  ...                         0.899902
# std                  486.282669  ...                         1.955783
# min                    0.059000  ...                         0.000000
# 25%                   13.303500  ...                         0.034000
# 50%                  803.372000  ...                         0.143000
# 75%                 1057.451000  ...                         0.578500
# max                 1090.806000  ...                        12.274000
#
#        reproduction_rate  icu_patients  icu_patients_per_million
# count        1029.000000   1139.000000               1139.000000  \
# mean            1.044208    282.170325                  8.314241
# std             0.273341    399.724115                 11.777988
# min             0.510000      0.000000                  0.000000
# 25%             0.880000     29.000000                  0.854000
# 50%             1.010000     96.000000                  2.829000
# 75%             1.160000    351.000000                 10.342000
# max             2.540000   1593.000000                 46.938000
#
#        hosp_patients  hosp_patients_per_million  weekly_icu_admissions
# count    1139.000000                1139.000000                    0.0  \
# mean     2769.296752                  81.598185                    NaN
# std      3278.015794                  96.587744                    NaN
# min        39.000000                   1.149000                    NaN
# 25%       485.000000                  14.291000                    NaN
# 50%      1501.000000                  44.227000                    NaN
# 75%      3823.500000                 112.661000                    NaN
# max     14753.000000                 434.702000                    NaN
#
#        weekly_icu_admissions_per_million  weekly_hosp_admissions
# count                                0.0             1133.000000  \
# mean                                 NaN             3675.713151
# std                                  NaN             4006.338005
# min                                  NaN               27.000000
# 25%                                  NaN              744.000000
# 50%                                  NaN             2384.000000
# 75%                                  NaN             4740.000000
# max                                  NaN            16562.000000
#
#        weekly_hosp_admissions_per_million
# count                         1133.000000
# mean                           108.306016
# std                            118.047999
# min                              0.796000
# 25%                             21.922000
# 50%                             70.245000
# 75%                            139.666000
# max                            488.004000
#
# [8 rows x 21 columns]

# %%
CovidDeathsNew = CovidDeaths.drop(CovidDeaths.columns[0:3],axis=1)

# %%
CovidDeathsNew
# Out:
#             date  population  total_cases new_cases  new_cases_smoothed
# 161452  3/1/2020    33938216          NaN       0.0                 NaN  \
# 161453  4/1/2020    33938216          NaN       0.0                 NaN
# 161454  5/1/2020    33938216          NaN       0.0                 NaN
# 161455  6/1/2020    33938216          NaN       0.0                 NaN
# 161456  7/1/2020    33938216          NaN       0.0                 NaN
# ...          ...         ...          ...       ...                 ...
# 162669  4/5/2023    33938216          NaN       NaN                 NaN
# 162670  5/5/2023    33938216          NaN       NaN                 NaN
# 162671  6/5/2023    33938216          NaN       NaN                 NaN
# 162672  7/5/2023    33938216          NaN       NaN                 NaN
# 162673  8/5/2023    33938216          NaN       NaN                 NaN
#
#         total_deaths  new_deaths  new_deaths_smoothed
# 161452           NaN         0.0                  NaN  \
# 161453           NaN         0.0                  NaN
# 161454           NaN         0.0                  NaN
# 161455           NaN         0.0                  NaN
# 161456           NaN         0.0                  NaN
# ...              ...         ...                  ...
# 162669           NaN         NaN                  NaN
# 162670           NaN         NaN                  NaN
# 162671           NaN         NaN                  NaN
# 162672           NaN         NaN                  NaN
# 162673           NaN         NaN                  NaN
#
#         total_cases_per_million  new_cases_per_million  ...
# 161452                      NaN                    0.0  ...  \
# 161453                      NaN                    0.0  ...
# 161454                      NaN                    0.0  ...
# 161455                      NaN                    0.0  ...
# 161456                      NaN                    0.0  ...
# ...                         ...                    ...  ...
# 162669                      NaN                    NaN  ...
# 162670                      NaN                    NaN  ...
# 162671                      NaN                    NaN  ...
# 162672                      NaN                    NaN  ...
# 162673                      NaN                    NaN  ...
#
#         new_deaths_smoothed_per_million  reproduction_rate  icu_patients
# 161452                              NaN                NaN           NaN  \
# 161453                              NaN                NaN           NaN
# 161454                              NaN                NaN           NaN
# 161455                              NaN                NaN           NaN
# 161456                              NaN                NaN           NaN
# ...                                 ...                ...           ...
# 162669                              NaN                NaN          43.0
# 162670                              NaN                NaN          44.0
# 162671                              NaN                NaN          41.0
# 162672                              NaN                NaN           NaN
# 162673                              NaN                NaN           NaN
#
#         icu_patients_per_million  hosp_patients  hosp_patients_per_million
# 161452                       NaN            NaN                        NaN  \
# 161453                       NaN            NaN                        NaN
# 161454                       NaN            NaN                        NaN
# 161455                       NaN            NaN                        NaN
# 161456                       NaN            NaN                        NaN
# ...                          ...            ...                        ...
# 162669                     1.267          774.0                     22.806
# 162670                     1.296          762.0                     22.453
# 162671                     1.208          766.0                     22.570
# 162672                       NaN            NaN                        NaN
# 162673                       NaN            NaN                        NaN
#
#         weekly_icu_admissions  weekly_icu_admissions_per_million
# 161452                    NaN                                NaN  \
# 161453                    NaN                                NaN
# 161454                    NaN                                NaN
# 161455                    NaN                                NaN
# 161456                    NaN                                NaN
# ...                       ...                                ...
# 162669                    NaN                                NaN
# 162670                    NaN                                NaN
# 162671                    NaN                                NaN
# 162672                    NaN                                NaN
# 162673                    NaN                                NaN
#
#         weekly_hosp_admissions  weekly_hosp_admissions_per_million
# 161452                     NaN                                 NaN
# 161453                     NaN                                 NaN
# 161454                     NaN                                 NaN
# 161455                     NaN                                 NaN
# 161456                     NaN                                 NaN
# ...                        ...                                 ...
# 162669                  1665.0                              49.060
# 162670                  1658.0                              48.853
# 162671                  1672.0                              49.266
# 162672                     NaN                                 NaN
# 162673                     NaN                                 NaN
#
# [1222 rows x 23 columns]

# %%
profile = pp.ProfileReport(CovidDeathsNew)
profile.to_file("CovidDeathsNew.html")
# Out:
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
# Generate report structure:   0%|          | 0/1 [00:00<?, ?it/s]
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %% [markdown]
# # CHECKING NULL DATA AND TREATING MISSING VALUE

# %%
CovidDeathsNew.isnull().sum()
# Out:
# date                                     0
# population                               0
# total_cases                             28
# new_cases                                7
# new_cases_smoothed                      12
# total_deaths                            79
# new_deaths                               5
# new_deaths_smoothed                     10
# total_cases_per_million                 28
# new_cases_per_million                    7
# new_cases_smoothed_per_million          12
# total_deaths_per_million                79
# new_deaths_per_million                   5
# new_deaths_smoothed_per_million         10
# reproduction_rate                      193
# icu_patients                            83
# icu_patients_per_million                83
# hosp_patients                           83
# hosp_patients_per_million               83
# weekly_icu_admissions                 1222
# weekly_icu_admissions_per_million     1222
# weekly_hosp_admissions                  89
# weekly_hosp_admissions_per_million      89
# dtype: int64

# %%
#Notice that all row in weekly_icu_admissions is Null
#remove all row related to that column
CovidDeathsNew = CovidDeathsNew.drop(columns=['weekly_icu_admissions', 'weekly_icu_admissions_per_million'])

# %%
CovidDeathsNew.isnull().sum()
# Out:
# date                                    0
# population                              0
# total_cases                            28
# new_cases                               7
# new_cases_smoothed                     12
# total_deaths                           79
# new_deaths                              5
# new_deaths_smoothed                    10
# total_cases_per_million                28
# new_cases_per_million                   7
# new_cases_smoothed_per_million         12
# total_deaths_per_million               79
# new_deaths_per_million                  5
# new_deaths_smoothed_per_million        10
# reproduction_rate                     193
# icu_patients                           83
# icu_patients_per_million               83
# hosp_patients                          83
# hosp_patients_per_million              83
# weekly_hosp_admissions                 89
# weekly_hosp_admissions_per_million     89
# dtype: int64

# %%
#Locate the row of Missing Values
trace_missing_total_cases = pd.isnull(CovidDeathsNew['total_cases'])
CovidDeathsNew[trace_missing_total_cases]
# Out:
#              date  population  total_cases new_cases  new_cases_smoothed
# 161452   3/1/2020    33938216          NaN       0.0                 NaN  \
# 161453   4/1/2020    33938216          NaN       0.0                 NaN
# 161454   5/1/2020    33938216          NaN       0.0                 NaN
# 161455   6/1/2020    33938216          NaN       0.0                 NaN
# 161456   7/1/2020    33938216          NaN       0.0                 NaN
# 161457   8/1/2020    33938216          NaN       0.0                 0.0
# 161458   9/1/2020    33938216          NaN       0.0                 0.0
# 161459  10/1/2020    33938216          NaN       0.0                 0.0
# 161460  11/1/2020    33938216          NaN       0.0                 0.0
# 161461  12/1/2020    33938216          NaN       0.0                 0.0
# 161462  13/1/2020    33938216          NaN       0.0                 0.0
# 161463  14/1/2020    33938216          NaN       0.0                 0.0
# 161464  15/1/2020    33938216          NaN       0.0                 0.0
# 161465  16/1/2020    33938216          NaN       0.0                 0.0
# 161466  17/1/2020    33938216          NaN       0.0                 0.0
# 161467  18/1/2020    33938216          NaN       0.0                 0.0
# 161468  19/1/2020    33938216          NaN       0.0                 0.0
# 161469  20/1/2020    33938216          NaN       0.0                 0.0
# 161470  21/1/2020    33938216          NaN       0.0                 0.0
# 161471  22/1/2020    33938216          NaN       0.0                 0.0
# 161472  23/1/2020    33938216          NaN       0.0                 0.0
# 161473  24/1/2020    33938216          NaN       0.0                 0.0
# 161474  25/1/2020    33938216          NaN       0.0                 0.0
# 162669   4/5/2023    33938216          NaN       NaN                 NaN
# 162670   5/5/2023    33938216          NaN       NaN                 NaN
# 162671   6/5/2023    33938216          NaN       NaN                 NaN
# 162672   7/5/2023    33938216          NaN       NaN                 NaN
# 162673   8/5/2023    33938216          NaN       NaN                 NaN
#
#         total_deaths  new_deaths  new_deaths_smoothed
# 161452           NaN         0.0                  NaN  \
# 161453           NaN         0.0                  NaN
# 161454           NaN         0.0                  NaN
# 161455           NaN         0.0                  NaN
# 161456           NaN         0.0                  NaN
# 161457           NaN         0.0                  0.0
# 161458           NaN         0.0                  0.0
# 161459           NaN         0.0                  0.0
# 161460           NaN         0.0                  0.0
# 161461           NaN         0.0                  0.0
# 161462           NaN         0.0                  0.0
# 161463           NaN         0.0                  0.0
# 161464           NaN         0.0                  0.0
# 161465           NaN         0.0                  0.0
# 161466           NaN         0.0                  0.0
# 161467           NaN         0.0                  0.0
# 161468           NaN         0.0                  0.0
# 161469           NaN         0.0                  0.0
# 161470           NaN         0.0                  0.0
# 161471           NaN         0.0                  0.0
# 161472           NaN         0.0                  0.0
# 161473           NaN         0.0                  0.0
# 161474           NaN         0.0                  0.0
# 162669           NaN         NaN                  NaN
# 162670           NaN         NaN                  NaN
# 162671           NaN         NaN                  NaN
# 162672           NaN         NaN                  NaN
# 162673           NaN         NaN                  NaN
#
#         total_cases_per_million  new_cases_per_million  ...
# 161452                      NaN                    0.0  ...  \
# 161453                      NaN                    0.0  ...
# 161454                      NaN                    0.0  ...
# 161455                      NaN                    0.0  ...
# 161456                      NaN                    0.0  ...
# 161457                      NaN                    0.0  ...
# 161458                      NaN                    0.0  ...
# 161459                      NaN                    0.0  ...
# 161460                      NaN                    0.0  ...
# 161461                      NaN                    0.0  ...
# 161462                      NaN                    0.0  ...
# 161463                      NaN                    0.0  ...
# 161464                      NaN                    0.0  ...
# 161465                      NaN                    0.0  ...
# 161466                      NaN                    0.0  ...
# 161467                      NaN                    0.0  ...
# 161468                      NaN                    0.0  ...
# 161469                      NaN                    0.0  ...
# 161470                      NaN                    0.0  ...
# 161471                      NaN                    0.0  ...
# 161472                      NaN                    0.0  ...
# 161473                      NaN                    0.0  ...
# 161474                      NaN                    0.0  ...
# 162669                      NaN                    NaN  ...
# 162670                      NaN                    NaN  ...
# 162671                      NaN                    NaN  ...
# 162672                      NaN                    NaN  ...
# 162673                      NaN                    NaN  ...
#
#         total_deaths_per_million  new_deaths_per_million
# 161452                       NaN                     0.0  \
# 161453                       NaN                     0.0
# 161454                       NaN                     0.0
# 161455                       NaN                     0.0
# 161456                       NaN                     0.0
# 161457                       NaN                     0.0
# 161458                       NaN                     0.0
# 161459                       NaN                     0.0
# 161460                       NaN                     0.0
# 161461                       NaN                     0.0
# 161462                       NaN                     0.0
# 161463                       NaN                     0.0
# 161464                       NaN                     0.0
# 161465                       NaN                     0.0
# 161466                       NaN                     0.0
# 161467                       NaN                     0.0
# 161468                       NaN                     0.0
# 161469                       NaN                     0.0
# 161470                       NaN                     0.0
# 161471                       NaN                     0.0
# 161472                       NaN                     0.0
# 161473                       NaN                     0.0
# 161474                       NaN                     0.0
# 162669                       NaN                     NaN
# 162670                       NaN                     NaN
# 162671                       NaN                     NaN
# 162672                       NaN                     NaN
# 162673                       NaN                     NaN
#
#         new_deaths_smoothed_per_million  reproduction_rate  icu_patients
# 161452                              NaN                NaN           NaN  \
# 161453                              NaN                NaN           NaN
# 161454                              NaN                NaN           NaN
# 161455                              NaN                NaN           NaN
# 161456                              NaN                NaN           NaN
# 161457                              0.0                NaN           NaN
# 161458                              0.0                NaN           NaN
# 161459                              0.0                NaN           NaN
# 161460                              0.0                NaN           NaN
# 161461                              0.0                NaN           NaN
# 161462                              0.0                NaN           NaN
# 161463                              0.0                NaN           NaN
# 161464                              0.0                NaN           NaN
# 161465                              0.0                NaN           NaN
# 161466                              0.0                NaN           NaN
# 161467                              0.0                NaN           NaN
# 161468                              0.0                NaN           NaN
# 161469                              0.0                NaN           NaN
# 161470                              0.0                NaN           NaN
# 161471                              0.0                NaN           NaN
# 161472                              0.0                NaN           NaN
# 161473                              0.0                NaN           NaN
# 161474                              0.0                NaN           NaN
# 162669                              NaN                NaN          43.0
# 162670                              NaN                NaN          44.0
# 162671                              NaN                NaN          41.0
# 162672                              NaN                NaN           NaN
# 162673                              NaN                NaN           NaN
#
#         icu_patients_per_million  hosp_patients  hosp_patients_per_million
# 161452                       NaN            NaN                        NaN  \
# 161453                       NaN            NaN                        NaN
# 161454                       NaN            NaN                        NaN
# 161455                       NaN            NaN                        NaN
# 161456                       NaN            NaN                        NaN
# 161457                       NaN            NaN                        NaN
# 161458                       NaN            NaN                        NaN
# 161459                       NaN            NaN                        NaN
# 161460                       NaN            NaN                        NaN
# 161461                       NaN            NaN                        NaN
# 161462                       NaN            NaN                        NaN
# 161463                       NaN            NaN                        NaN
# 161464                       NaN            NaN                        NaN
# 161465                       NaN            NaN                        NaN
# 161466                       NaN            NaN                        NaN
# 161467                       NaN            NaN                        NaN
# 161468                       NaN            NaN                        NaN
# 161469                       NaN            NaN                        NaN
# 161470                       NaN            NaN                        NaN
# 161471                       NaN            NaN                        NaN
# 161472                       NaN            NaN                        NaN
# 161473                       NaN            NaN                        NaN
# 161474                       NaN            NaN                        NaN
# 162669                     1.267          774.0                     22.806
# 162670                     1.296          762.0                     22.453
# 162671                     1.208          766.0                     22.570
# 162672                       NaN            NaN                        NaN
# 162673                       NaN            NaN                        NaN
#
#         weekly_hosp_admissions  weekly_hosp_admissions_per_million
# 161452                     NaN                                 NaN
# 161453                     NaN                                 NaN
# 161454                     NaN                                 NaN
# 161455                     NaN                                 NaN
# 161456                     NaN                                 NaN
# 161457                     NaN                                 NaN
# 161458                     NaN                                 NaN
# 161459                     NaN                                 NaN
# 161460                     NaN                                 NaN
# 161461                     NaN                                 NaN
# 161462                     NaN                                 NaN
# 161463                     NaN                                 NaN
# 161464                     NaN                                 NaN
# 161465                     NaN                                 NaN
# 161466                     NaN                                 NaN
# 161467                     NaN                                 NaN
# 161468                     NaN                                 NaN
# 161469                     NaN                                 NaN
# 161470                     NaN                                 NaN
# 161471                     NaN                                 NaN
# 161472                     NaN                                 NaN
# 161473                     NaN                                 NaN
# 161474                     NaN                                 NaN
# 162669                  1665.0                              49.060
# 162670                  1658.0                              48.853
# 162671                  1672.0                              49.266
# 162672                     NaN                                 NaN
# 162673                     NaN                                 NaN
#
# [28 rows x 21 columns]

# %%
#Replace with zero
CovidDeathsNew.total_cases = CovidDeathsNew.total_cases.fillna(0) #By Column

# %%
CovidDeathsNew.isnull().sum()
# Out:
# date                                    0
# population                              0
# total_cases                             0
# new_cases                               7
# new_cases_smoothed                     12
# total_deaths                           79
# new_deaths                              5
# new_deaths_smoothed                    10
# total_cases_per_million                28
# new_cases_per_million                   7
# new_cases_smoothed_per_million         12
# total_deaths_per_million               79
# new_deaths_per_million                  5
# new_deaths_smoothed_per_million        10
# reproduction_rate                     193
# icu_patients                           83
# icu_patients_per_million               83
# hosp_patients                          83
# hosp_patients_per_million              83
# weekly_hosp_admissions                 89
# weekly_hosp_admissions_per_million     89
# dtype: int64

# %%
#Locate the row of Missing Values
trace_missing_new_cases = pd.isnull(CovidDeathsNew['new_cases'])
CovidDeathsNew[trace_missing_new_cases]
# Out:
#             date  population  total_cases new_cases  new_cases_smoothed
# 162667  2/5/2023    33938216    5071840.0       NaN                 NaN  \
# 162668  3/5/2023    33938216    5071840.0       NaN                 NaN
# 162669  4/5/2023    33938216          0.0       NaN                 NaN
# 162670  5/5/2023    33938216          0.0       NaN                 NaN
# 162671  6/5/2023    33938216          0.0       NaN                 NaN
# 162672  7/5/2023    33938216          0.0       NaN                 NaN
# 162673  8/5/2023    33938216          0.0       NaN                 NaN
#
#         total_deaths  new_deaths  new_deaths_smoothed
# 162667       37020.0         0.0                1.286  \
# 162668       37020.0         0.0                1.286
# 162669           NaN         NaN                  NaN
# 162670           NaN         NaN                  NaN
# 162671           NaN         NaN                  NaN
# 162672           NaN         NaN                  NaN
# 162673           NaN         NaN                  NaN
#
#         total_cases_per_million  new_cases_per_million  ...
# 162667                149443.33                    NaN  ...  \
# 162668                149443.33                    NaN  ...
# 162669                      NaN                    NaN  ...
# 162670                      NaN                    NaN  ...
# 162671                      NaN                    NaN  ...
# 162672                      NaN                    NaN  ...
# 162673                      NaN                    NaN  ...
#
#         total_deaths_per_million  new_deaths_per_million
# 162667                  1090.806                     0.0  \
# 162668                  1090.806                     0.0
# 162669                       NaN                     NaN
# 162670                       NaN                     NaN
# 162671                       NaN                     NaN
# 162672                       NaN                     NaN
# 162673                       NaN                     NaN
#
#         new_deaths_smoothed_per_million  reproduction_rate  icu_patients
# 162667                            0.038                NaN          41.0  \
# 162668                            0.038                NaN          44.0
# 162669                              NaN                NaN          43.0
# 162670                              NaN                NaN          44.0
# 162671                              NaN                NaN          41.0
# 162672                              NaN                NaN           NaN
# 162673                              NaN                NaN           NaN
#
#         icu_patients_per_million  hosp_patients  hosp_patients_per_million
# 162667                     1.208          725.0                     21.362  \
# 162668                     1.296          772.0                     22.747
# 162669                     1.267          774.0                     22.806
# 162670                     1.296          762.0                     22.453
# 162671                     1.208          766.0                     22.570
# 162672                       NaN            NaN                        NaN
# 162673                       NaN            NaN                        NaN
#
#         weekly_hosp_admissions  weekly_hosp_admissions_per_million
# 162667                  1538.0                              45.318
# 162668                  1593.0                              46.938
# 162669                  1665.0                              49.060
# 162670                  1658.0                              48.853
# 162671                  1672.0                              49.266
# 162672                     NaN                                 NaN
# 162673                     NaN                                 NaN
#
# [7 rows x 21 columns]

# %%
#Replace with zero
CovidDeathsNew.new_cases = CovidDeathsNew.new_cases.fillna(0) #By Column

# %%
CovidDeathsNew.isnull().sum()
# Out:
# date                                    0
# population                              0
# total_cases                             0
# new_cases                               0
# new_cases_smoothed                     12
# total_deaths                           79
# new_deaths                              5
# new_deaths_smoothed                    10
# total_cases_per_million                28
# new_cases_per_million                   7
# new_cases_smoothed_per_million         12
# total_deaths_per_million               79
# new_deaths_per_million                  5
# new_deaths_smoothed_per_million        10
# reproduction_rate                     193
# icu_patients                           83
# icu_patients_per_million               83
# hosp_patients                          83
# hosp_patients_per_million              83
# weekly_hosp_admissions                 89
# weekly_hosp_admissions_per_million     89
# dtype: int64

# %%
#Locate the row of Missing Values
trace_missing_new_cases_smoothed = pd.isnull(CovidDeathsNew['new_cases_smoothed'])
CovidDeathsNew[trace_missing_new_cases_smoothed]
# Out:
#             date  population  total_cases  new_cases  new_cases_smoothed
# 161452  3/1/2020    33938216          0.0        0.0                 NaN  \
# 161453  4/1/2020    33938216          0.0        0.0                 NaN
# 161454  5/1/2020    33938216          0.0        0.0                 NaN
# 161455  6/1/2020    33938216          0.0        0.0                 NaN
# 161456  7/1/2020    33938216          0.0        0.0                 NaN
# 162667  2/5/2023    33938216    5071840.0        0.0                 NaN
# 162668  3/5/2023    33938216    5071840.0        0.0                 NaN
# 162669  4/5/2023    33938216          0.0        0.0                 NaN
# 162670  5/5/2023    33938216          0.0        0.0                 NaN
# 162671  6/5/2023    33938216          0.0        0.0                 NaN
# 162672  7/5/2023    33938216          0.0        0.0                 NaN
# 162673  8/5/2023    33938216          0.0        0.0                 NaN
#
#         total_deaths  new_deaths  new_deaths_smoothed
# 161452           NaN         0.0                  NaN  \
# 161453           NaN         0.0                  NaN
# 161454           NaN         0.0                  NaN
# 161455           NaN         0.0                  NaN
# 161456           NaN         0.0                  NaN
# 162667       37020.0         0.0                1.286
# 162668       37020.0         0.0                1.286
# 162669           NaN         NaN                  NaN
# 162670           NaN         NaN                  NaN
# 162671           NaN         NaN                  NaN
# 162672           NaN         NaN                  NaN
# 162673           NaN         NaN                  NaN
#
#         total_cases_per_million  new_cases_per_million  ...
# 161452                      NaN                    0.0  ...  \
# 161453                      NaN                    0.0  ...
# 161454                      NaN                    0.0  ...
# 161455                      NaN                    0.0  ...
# 161456                      NaN                    0.0  ...
# 162667                149443.33                    NaN  ...
# 162668                149443.33                    NaN  ...
# 162669                      NaN                    NaN  ...
# 162670                      NaN                    NaN  ...
# 162671                      NaN                    NaN  ...
# 162672                      NaN                    NaN  ...
# 162673                      NaN                    NaN  ...
#
#         total_deaths_per_million  new_deaths_per_million
# 161452                       NaN                     0.0  \
# 161453                       NaN                     0.0
# 161454                       NaN                     0.0
# 161455                       NaN                     0.0
# 161456                       NaN                     0.0
# 162667                  1090.806                     0.0
# 162668                  1090.806                     0.0
# 162669                       NaN                     NaN
# 162670                       NaN                     NaN
# 162671                       NaN                     NaN
# 162672                       NaN                     NaN
# 162673                       NaN                     NaN
#
#         new_deaths_smoothed_per_million  reproduction_rate  icu_patients
# 161452                              NaN                NaN           NaN  \
# 161453                              NaN                NaN           NaN
# 161454                              NaN                NaN           NaN
# 161455                              NaN                NaN           NaN
# 161456                              NaN                NaN           NaN
# 162667                            0.038                NaN          41.0
# 162668                            0.038                NaN          44.0
# 162669                              NaN                NaN          43.0
# 162670                              NaN                NaN          44.0
# 162671                              NaN                NaN          41.0
# 162672                              NaN                NaN           NaN
# 162673                              NaN                NaN           NaN
#
#         icu_patients_per_million  hosp_patients  hosp_patients_per_million
# 161452                       NaN            NaN                        NaN  \
# 161453                       NaN            NaN                        NaN
# 161454                       NaN            NaN                        NaN
# 161455                       NaN            NaN                        NaN
# 161456                       NaN            NaN                        NaN
# 162667                     1.208          725.0                     21.362
# 162668                     1.296          772.0                     22.747
# 162669                     1.267          774.0                     22.806
# 162670                     1.296          762.0                     22.453
# 162671                     1.208          766.0                     22.570
# 162672                       NaN            NaN                        NaN
# 162673                       NaN            NaN                        NaN
#
#         weekly_hosp_admissions  weekly_hosp_admissions_per_million
# 161452                     NaN                                 NaN
# 161453                     NaN                                 NaN
# 161454                     NaN                                 NaN
# 161455                     NaN                                 NaN
# 161456                     NaN                                 NaN
# 162667                  1538.0                              45.318
# 162668                  1593.0                              46.938
# 162669                  1665.0                              49.060
# 162670                  1658.0                              48.853
# 162671                  1672.0                              49.266
# 162672                     NaN                                 NaN
# 162673                     NaN                                 NaN
#
# [12 rows x 21 columns]

# %%
#Replace with zero
CovidDeathsNew.new_cases_smoothed = CovidDeathsNew.new_cases_smoothed.fillna(0) #By Column

# %%
CovidDeathsNew.isnull().sum()
# Out:
# date                                    0
# population                              0
# total_cases                             0
# new_cases                               0
# new_cases_smoothed                      0
# total_deaths                           79
# new_deaths                              5
# new_deaths_smoothed                    10
# total_cases_per_million                28
# new_cases_per_million                   7
# new_cases_smoothed_per_million         12
# total_deaths_per_million               79
# new_deaths_per_million                  5
# new_deaths_smoothed_per_million        10
# reproduction_rate                     193
# icu_patients                           83
# icu_patients_per_million               83
# hosp_patients                          83
# hosp_patients_per_million              83
# weekly_hosp_admissions                 89
# weekly_hosp_admissions_per_million     89
# dtype: int64

# %%
CovidDeathsNew.tail(10)
# Out:
#              date  population  total_cases  new_cases  new_cases_smoothed
# 162664  29/4/2023    33938216    5066877.0        0.0             688.143  \
# 162665  30/4/2023    33938216    5071694.0     4817.0             688.143
# 162666   1/5/2023    33938216    5071840.0      146.0             709.000
# 162667   2/5/2023    33938216    5071840.0        0.0               0.000
# 162668   3/5/2023    33938216    5071840.0        0.0               0.000
# 162669   4/5/2023    33938216          0.0        0.0               0.000
# 162670   5/5/2023    33938216          0.0        0.0               0.000
# 162671   6/5/2023    33938216          0.0        0.0               0.000
# 162672   7/5/2023    33938216          0.0        0.0               0.000
# 162673   8/5/2023    33938216          0.0        0.0               0.000
#
#         total_deaths  new_deaths  new_deaths_smoothed
# 162664       37011.0         0.0                1.571  \
# 162665       37020.0         9.0                2.857
# 162666       37020.0         0.0                1.286
# 162667       37020.0         0.0                1.286
# 162668       37020.0         0.0                1.286
# 162669           NaN         NaN                  NaN
# 162670           NaN         NaN                  NaN
# 162671           NaN         NaN                  NaN
# 162672           NaN         NaN                  NaN
# 162673           NaN         NaN                  NaN
#
#         total_cases_per_million  new_cases_per_million  ...
# 162664               149297.093                  0.000  ...  \
# 162665               149439.028                141.934  ...
# 162666               149443.330                  4.302  ...
# 162667               149443.330                    NaN  ...
# 162668               149443.330                    NaN  ...
# 162669                      NaN                    NaN  ...
# 162670                      NaN                    NaN  ...
# 162671                      NaN                    NaN  ...
# 162672                      NaN                    NaN  ...
# 162673                      NaN                    NaN  ...
#
#         total_deaths_per_million  new_deaths_per_million
# 162664                  1090.541                   0.000  \
# 162665                  1090.806                   0.265
# 162666                  1090.806                   0.000
# 162667                  1090.806                   0.000
# 162668                  1090.806                   0.000
# 162669                       NaN                     NaN
# 162670                       NaN                     NaN
# 162671                       NaN                     NaN
# 162672                       NaN                     NaN
# 162673                       NaN                     NaN
#
#         new_deaths_smoothed_per_million  reproduction_rate  icu_patients
# 162664                            0.046                NaN          29.0  \
# 162665                            0.084                NaN          64.0
# 162666                            0.038                NaN          41.0
# 162667                            0.038                NaN          41.0
# 162668                            0.038                NaN          44.0
# 162669                              NaN                NaN          43.0
# 162670                              NaN                NaN          44.0
# 162671                              NaN                NaN          41.0
# 162672                              NaN                NaN           NaN
# 162673                              NaN                NaN           NaN
#
#         icu_patients_per_million  hosp_patients  hosp_patients_per_million
# 162664                     0.854          673.0                     19.830  \
# 162665                     1.886          737.0                     21.716
# 162666                     1.208          767.0                     22.600
# 162667                     1.208          725.0                     21.362
# 162668                     1.296          772.0                     22.747
# 162669                     1.267          774.0                     22.806
# 162670                     1.296          762.0                     22.453
# 162671                     1.208          766.0                     22.570
# 162672                       NaN            NaN                        NaN
# 162673                       NaN            NaN                        NaN
#
#         weekly_hosp_admissions  weekly_hosp_admissions_per_million
# 162664                  1194.0                              35.182
# 162665                  1345.0                              39.631
# 162666                  1462.0                              43.078
# 162667                  1538.0                              45.318
# 162668                  1593.0                              46.938
# 162669                  1665.0                              49.060
# 162670                  1658.0                              48.853
# 162671                  1672.0                              49.266
# 162672                     NaN                                 NaN
# 162673                     NaN                                 NaN
#
# [10 rows x 21 columns]

# %%
CovidDeathsNew.drop(CovidDeathsNew.tail(5).index,inplace=True) # drop last n rows

# %%
CovidDeathsNew.tail(10)
# Out:
#              date  population  total_cases  new_cases  new_cases_smoothed
# 162659  24/4/2023    33938216    5066877.0        0.0             814.000  \
# 162660  25/4/2023    33938216    5066877.0        0.0             688.143
# 162661  26/4/2023    33938216    5066877.0        0.0             688.143
# 162662  27/4/2023    33938216    5066877.0        0.0             688.143
# 162663  28/4/2023    33938216    5066877.0        0.0             688.143
# 162664  29/4/2023    33938216    5066877.0        0.0             688.143
# 162665  30/4/2023    33938216    5071694.0     4817.0             688.143
# 162666   1/5/2023    33938216    5071840.0      146.0             709.000
# 162667   2/5/2023    33938216    5071840.0        0.0               0.000
# 162668   3/5/2023    33938216    5071840.0        0.0               0.000
#
#         total_deaths  new_deaths  new_deaths_smoothed
# 162659       37011.0        11.0                2.429  \
# 162660       37011.0         0.0                1.571
# 162661       37011.0         0.0                1.571
# 162662       37011.0         0.0                1.571
# 162663       37011.0         0.0                1.571
# 162664       37011.0         0.0                1.571
# 162665       37020.0         9.0                2.857
# 162666       37020.0         0.0                1.286
# 162667       37020.0         0.0                1.286
# 162668       37020.0         0.0                1.286
#
#         total_cases_per_million  new_cases_per_million  ...
# 162659               149297.093                  0.000  ...  \
# 162660               149297.093                  0.000  ...
# 162661               149297.093                  0.000  ...
# 162662               149297.093                  0.000  ...
# 162663               149297.093                  0.000  ...
# 162664               149297.093                  0.000  ...
# 162665               149439.028                141.934  ...
# 162666               149443.330                  4.302  ...
# 162667               149443.330                    NaN  ...
# 162668               149443.330                    NaN  ...
#
#         total_deaths_per_million  new_deaths_per_million
# 162659                  1090.541                   0.324  \
# 162660                  1090.541                   0.000
# 162661                  1090.541                   0.000
# 162662                  1090.541                   0.000
# 162663                  1090.541                   0.000
# 162664                  1090.541                   0.000
# 162665                  1090.806                   0.265
# 162666                  1090.806                   0.000
# 162667                  1090.806                   0.000
# 162668                  1090.806                   0.000
#
#         new_deaths_smoothed_per_million  reproduction_rate  icu_patients
# 162659                            0.072                NaN          29.0  \
# 162660                            0.046                NaN          25.0
# 162661                            0.046                NaN          27.0
# 162662                            0.046                NaN          26.0
# 162663                            0.046                NaN          31.0
# 162664                            0.046                NaN          29.0
# 162665                            0.084                NaN          64.0
# 162666                            0.038                NaN          41.0
# 162667                            0.038                NaN          41.0
# 162668                            0.038                NaN          44.0
#
#         icu_patients_per_million  hosp_patients  hosp_patients_per_million
# 162659                     0.854          374.0                     11.020  \
# 162660                     0.737          403.0                     11.875
# 162661                     0.796          486.0                     14.320
# 162662                     0.766          514.0                     15.145
# 162663                     0.913          626.0                     18.445
# 162664                     0.854          673.0                     19.830
# 162665                     1.886          737.0                     21.716
# 162666                     1.208          767.0                     22.600
# 162667                     1.208          725.0                     21.362
# 162668                     1.296          772.0                     22.747
#
#         weekly_hosp_admissions  weekly_hosp_admissions_per_million
# 162659                   849.0                              25.016
# 162660                   850.0                              25.046
# 162661                   920.0                              27.108
# 162662                   977.0                              28.788
# 162663                  1082.0                              31.881
# 162664                  1194.0                              35.182
# 162665                  1345.0                              39.631
# 162666                  1462.0                              43.078
# 162667                  1538.0                              45.318
# 162668                  1593.0                              46.938
#
# [10 rows x 21 columns]

# %%
CovidDeathsNew.isnull().sum()
# Out:
# date                                    0
# population                              0
# total_cases                             0
# new_cases                               0
# new_cases_smoothed                      0
# total_deaths                           74
# new_deaths                              0
# new_deaths_smoothed                     5
# total_cases_per_million                23
# new_cases_per_million                   2
# new_cases_smoothed_per_million          7
# total_deaths_per_million               74
# new_deaths_per_million                  0
# new_deaths_smoothed_per_million         5
# reproduction_rate                     188
# icu_patients                           81
# icu_patients_per_million               81
# hosp_patients                          81
# hosp_patients_per_million              81
# weekly_hosp_admissions                 87
# weekly_hosp_admissions_per_million     87
# dtype: int64

# %%
#Locate the row of Missing Values
trace_missing_total_deaths = pd.isnull(CovidDeathsNew['total_deaths'])
CovidDeathsNew[trace_missing_total_deaths]
# Out:
#              date  population  total_cases  new_cases  new_cases_smoothed
# 161452   3/1/2020    33938216          0.0        0.0               0.000  \
# 161453   4/1/2020    33938216          0.0        0.0               0.000
# 161454   5/1/2020    33938216          0.0        0.0               0.000
# 161455   6/1/2020    33938216          0.0        0.0               0.000
# 161456   7/1/2020    33938216          0.0        0.0               0.000
# ...           ...         ...          ...        ...                 ...
# 161521  12/3/2020    33938216        149.0       32.0              14.143
# 161522  13/3/2020    33938216        158.0        9.0              14.714
# 161523  14/3/2020    33938216        197.0       39.0              16.286
# 161524  15/3/2020    33938216        238.0       41.0              20.714
# 161525  16/3/2020    33938216        428.0      190.0              47.000
#
#         total_deaths  new_deaths  new_deaths_smoothed
# 161452           NaN         0.0                  NaN  \
# 161453           NaN         0.0                  NaN
# 161454           NaN         0.0                  NaN
# 161455           NaN         0.0                  NaN
# 161456           NaN         0.0                  NaN
# ...              ...         ...                  ...
# 161521           NaN         0.0                  0.0
# 161522           NaN         0.0                  0.0
# 161523           NaN         0.0                  0.0
# 161524           NaN         0.0                  0.0
# 161525           NaN         0.0                  0.0
#
#         total_cases_per_million  new_cases_per_million  ...
# 161452                      NaN                  0.000  ...  \
# 161453                      NaN                  0.000  ...
# 161454                      NaN                  0.000  ...
# 161455                      NaN                  0.000  ...
# 161456                      NaN                  0.000  ...
# ...                         ...                    ...  ...
# 161521                    4.390                  0.943  ...
# 161522                    4.656                  0.265  ...
# 161523                    5.805                  1.149  ...
# 161524                    7.013                  1.208  ...
# 161525                   12.611                  5.598  ...
#
#         total_deaths_per_million  new_deaths_per_million
# 161452                       NaN                     0.0  \
# 161453                       NaN                     0.0
# 161454                       NaN                     0.0
# 161455                       NaN                     0.0
# 161456                       NaN                     0.0
# ...                          ...                     ...
# 161521                       NaN                     0.0
# 161522                       NaN                     0.0
# 161523                       NaN                     0.0
# 161524                       NaN                     0.0
# 161525                       NaN                     0.0
#
#         new_deaths_smoothed_per_million  reproduction_rate  icu_patients
# 161452                              NaN                NaN           NaN  \
# 161453                              NaN                NaN           NaN
# 161454                              NaN                NaN           NaN
# 161455                              NaN                NaN           NaN
# 161456                              NaN                NaN           NaN
# ...                                 ...                ...           ...
# 161521                              0.0               2.16           NaN
# 161522                              0.0               2.30           NaN
# 161523                              0.0               2.42           NaN
# 161524                              0.0               2.54           NaN
# 161525                              0.0               2.43           NaN
#
#         icu_patients_per_million  hosp_patients  hosp_patients_per_million
# 161452                       NaN            NaN                        NaN  \
# 161453                       NaN            NaN                        NaN
# 161454                       NaN            NaN                        NaN
# 161455                       NaN            NaN                        NaN
# 161456                       NaN            NaN                        NaN
# ...                          ...            ...                        ...
# 161521                       NaN            NaN                        NaN
# 161522                       NaN            NaN                        NaN
# 161523                       NaN            NaN                        NaN
# 161524                       NaN            NaN                        NaN
# 161525                       NaN            NaN                        NaN
#
#         weekly_hosp_admissions  weekly_hosp_admissions_per_million
# 161452                     NaN                                 NaN
# 161453                     NaN                                 NaN
# 161454                     NaN                                 NaN
# 161455                     NaN                                 NaN
# 161456                     NaN                                 NaN
# ...                        ...                                 ...
# 161521                     NaN                                 NaN
# 161522                     NaN                                 NaN
# 161523                     NaN                                 NaN
# 161524                     NaN                                 NaN
# 161525                     NaN                                 NaN
#
# [74 rows x 21 columns]

# %%
#Replace with zero
CovidDeathsNew.total_deaths = CovidDeathsNew.total_deaths.fillna(0) #By Column

# %%
CovidDeathsNew.isnull().sum()
# Out:
# date                                    0
# population                              0
# total_cases                             0
# new_cases                               0
# new_cases_smoothed                      0
# total_deaths                            0
# new_deaths                              0
# new_deaths_smoothed                     5
# total_cases_per_million                23
# new_cases_per_million                   2
# new_cases_smoothed_per_million          7
# total_deaths_per_million               74
# new_deaths_per_million                  0
# new_deaths_smoothed_per_million         5
# reproduction_rate                     188
# icu_patients                           81
# icu_patients_per_million               81
# hosp_patients                          81
# hosp_patients_per_million              81
# weekly_hosp_admissions                 87
# weekly_hosp_admissions_per_million     87
# dtype: int64

# %%
#Locate the row of Missing Values
trace_missing_new_deaths_smoothed = pd.isnull(CovidDeathsNew['new_deaths_smoothed'])
CovidDeathsNew[trace_missing_new_deaths_smoothed]
# Out:
#             date  population  total_cases  new_cases  new_cases_smoothed
# 161452  3/1/2020    33938216          0.0        0.0                 0.0  \
# 161453  4/1/2020    33938216          0.0        0.0                 0.0
# 161454  5/1/2020    33938216          0.0        0.0                 0.0
# 161455  6/1/2020    33938216          0.0        0.0                 0.0
# 161456  7/1/2020    33938216          0.0        0.0                 0.0
#
#         total_deaths  new_deaths  new_deaths_smoothed
# 161452           0.0         0.0                  NaN  \
# 161453           0.0         0.0                  NaN
# 161454           0.0         0.0                  NaN
# 161455           0.0         0.0                  NaN
# 161456           0.0         0.0                  NaN
#
#         total_cases_per_million  new_cases_per_million  ...
# 161452                      NaN                    0.0  ...  \
# 161453                      NaN                    0.0  ...
# 161454                      NaN                    0.0  ...
# 161455                      NaN                    0.0  ...
# 161456                      NaN                    0.0  ...
#
#         total_deaths_per_million  new_deaths_per_million
# 161452                       NaN                     0.0  \
# 161453                       NaN                     0.0
# 161454                       NaN                     0.0
# 161455                       NaN                     0.0
# 161456                       NaN                     0.0
#
#         new_deaths_smoothed_per_million  reproduction_rate  icu_patients
# 161452                              NaN                NaN           NaN  \
# 161453                              NaN                NaN           NaN
# 161454                              NaN                NaN           NaN
# 161455                              NaN                NaN           NaN
# 161456                              NaN                NaN           NaN
#
#         icu_patients_per_million  hosp_patients  hosp_patients_per_million
# 161452                       NaN            NaN                        NaN  \
# 161453                       NaN            NaN                        NaN
# 161454                       NaN            NaN                        NaN
# 161455                       NaN            NaN                        NaN
# 161456                       NaN            NaN                        NaN
#
#         weekly_hosp_admissions  weekly_hosp_admissions_per_million
# 161452                     NaN                                 NaN
# 161453                     NaN                                 NaN
# 161454                     NaN                                 NaN
# 161455                     NaN                                 NaN
# 161456                     NaN                                 NaN
#
# [5 rows x 21 columns]

# %%
#Replace with zero
CovidDeathsNew.new_deaths_smoothed = CovidDeathsNew.new_deaths_smoothed.fillna(0) #By Column

# %%
CovidDeathsNew.isnull().sum()
# Out:
# date                                    0
# population                              0
# total_cases                             0
# new_cases                               0
# new_cases_smoothed                      0
# total_deaths                            0
# new_deaths                              0
# new_deaths_smoothed                     0
# total_cases_per_million                23
# new_cases_per_million                   2
# new_cases_smoothed_per_million          7
# total_deaths_per_million               74
# new_deaths_per_million                  0
# new_deaths_smoothed_per_million         5
# reproduction_rate                     188
# icu_patients                           81
# icu_patients_per_million               81
# hosp_patients                          81
# hosp_patients_per_million              81
# weekly_hosp_admissions                 87
# weekly_hosp_admissions_per_million     87
# dtype: int64

# %%
#Locate the row of Missing Values
trace_missing_reproduction_rate  = pd.isnull(CovidDeathsNew['reproduction_rate'])
CovidDeathsNew[trace_missing_reproduction_rate]
# Out:
#              date  population  total_cases  new_cases  new_cases_smoothed
# 161452   3/1/2020    33938216          0.0        0.0               0.000  \
# 161453   4/1/2020    33938216          0.0        0.0               0.000
# 161454   5/1/2020    33938216          0.0        0.0               0.000
# 161455   6/1/2020    33938216          0.0        0.0               0.000
# 161456   7/1/2020    33938216          0.0        0.0               0.000
# ...           ...         ...          ...        ...                 ...
# 162664  29/4/2023    33938216    5066877.0        0.0             688.143
# 162665  30/4/2023    33938216    5071694.0     4817.0             688.143
# 162666   1/5/2023    33938216    5071840.0      146.0             709.000
# 162667   2/5/2023    33938216    5071840.0        0.0               0.000
# 162668   3/5/2023    33938216    5071840.0        0.0               0.000
#
#         total_deaths  new_deaths  new_deaths_smoothed
# 161452           0.0         0.0                0.000  \
# 161453           0.0         0.0                0.000
# 161454           0.0         0.0                0.000
# 161455           0.0         0.0                0.000
# 161456           0.0         0.0                0.000
# ...              ...         ...                  ...
# 162664       37011.0         0.0                1.571
# 162665       37020.0         9.0                2.857
# 162666       37020.0         0.0                1.286
# 162667       37020.0         0.0                1.286
# 162668       37020.0         0.0                1.286
#
#         total_cases_per_million  new_cases_per_million  ...
# 161452                      NaN                  0.000  ...  \
# 161453                      NaN                  0.000  ...
# 161454                      NaN                  0.000  ...
# 161455                      NaN                  0.000  ...
# 161456                      NaN                  0.000  ...
# ...                         ...                    ...  ...
# 162664               149297.093                  0.000  ...
# 162665               149439.028                141.934  ...
# 162666               149443.330                  4.302  ...
# 162667               149443.330                    NaN  ...
# 162668               149443.330                    NaN  ...
#
#         total_deaths_per_million  new_deaths_per_million
# 161452                       NaN                   0.000  \
# 161453                       NaN                   0.000
# 161454                       NaN                   0.000
# 161455                       NaN                   0.000
# 161456                       NaN                   0.000
# ...                          ...                     ...
# 162664                  1090.541                   0.000
# 162665                  1090.806                   0.265
# 162666                  1090.806                   0.000
# 162667                  1090.806                   0.000
# 162668                  1090.806                   0.000
#
#         new_deaths_smoothed_per_million  reproduction_rate  icu_patients
# 161452                              NaN                NaN           NaN  \
# 161453                              NaN                NaN           NaN
# 161454                              NaN                NaN           NaN
# 161455                              NaN                NaN           NaN
# 161456                              NaN                NaN           NaN
# ...                                 ...                ...           ...
# 162664                            0.046                NaN          29.0
# 162665                            0.084                NaN          64.0
# 162666                            0.038                NaN          41.0
# 162667                            0.038                NaN          41.0
# 162668                            0.038                NaN          44.0
#
#         icu_patients_per_million  hosp_patients  hosp_patients_per_million
# 161452                       NaN            NaN                        NaN  \
# 161453                       NaN            NaN                        NaN
# 161454                       NaN            NaN                        NaN
# 161455                       NaN            NaN                        NaN
# 161456                       NaN            NaN                        NaN
# ...                          ...            ...                        ...
# 162664                     0.854          673.0                     19.830
# 162665                     1.886          737.0                     21.716
# 162666                     1.208          767.0                     22.600
# 162667                     1.208          725.0                     21.362
# 162668                     1.296          772.0                     22.747
#
#         weekly_hosp_admissions  weekly_hosp_admissions_per_million
# 161452                     NaN                                 NaN
# 161453                     NaN                                 NaN
# 161454                     NaN                                 NaN
# 161455                     NaN                                 NaN
# 161456                     NaN                                 NaN
# ...                        ...                                 ...
# 162664                  1194.0                              35.182
# 162665                  1345.0                              39.631
# 162666                  1462.0                              43.078
# 162667                  1538.0                              45.318
# 162668                  1593.0                              46.938
#
# [188 rows x 21 columns]

# %%
#Replace with mean
CovidDeathsNew.reproduction_rate= CovidDeathsNew.reproduction_rate.fillna(CovidDeathsNew.reproduction_rate.mean())

# %%
CovidDeathsNew.isnull().sum()
# Out:
# date                                   0
# population                             0
# total_cases                            0
# new_cases                              0
# new_cases_smoothed                     0
# total_deaths                           0
# new_deaths                             0
# new_deaths_smoothed                    0
# total_cases_per_million               23
# new_cases_per_million                  2
# new_cases_smoothed_per_million         7
# total_deaths_per_million              74
# new_deaths_per_million                 0
# new_deaths_smoothed_per_million        5
# reproduction_rate                      0
# icu_patients                          81
# icu_patients_per_million              81
# hosp_patients                         81
# hosp_patients_per_million             81
# weekly_hosp_admissions                87
# weekly_hosp_admissions_per_million    87
# dtype: int64

# %%
#Locate the row of Missing Values
trace_missing_weekly_hosp_admissions = pd.isnull(CovidDeathsNew['weekly_hosp_admissions'])
CovidDeathsNew[trace_missing_weekly_hosp_admissions]
# Out:
#              date  population  total_cases  new_cases  new_cases_smoothed
# 161452   3/1/2020    33938216          0.0        0.0               0.000  \
# 161453   4/1/2020    33938216          0.0        0.0               0.000
# 161454   5/1/2020    33938216          0.0        0.0               0.000
# 161455   6/1/2020    33938216          0.0        0.0               0.000
# 161456   7/1/2020    33938216          0.0        0.0               0.000
# ...           ...         ...          ...        ...                 ...
# 161534  25/3/2020    33938216       1624.0      106.0             135.857
# 161535  26/3/2020    33938216       1796.0      172.0             143.714
# 161536  27/3/2020    33938216       2031.0      235.0             161.571
# 161537  28/3/2020    33938216       2161.0      130.0             161.571
# 161538  29/3/2020    33938216       2320.0      159.0             162.429
#
#         total_deaths  new_deaths  new_deaths_smoothed
# 161452           0.0         0.0                0.000  \
# 161453           0.0         0.0                0.000
# 161454           0.0         0.0                0.000
# 161455           0.0         0.0                0.000
# 161456           0.0         0.0                0.000
# ...              ...         ...                  ...
# 161534          16.0         2.0                2.000
# 161535          19.0         3.0                2.429
# 161536          23.0         4.0                2.857
# 161537          26.0         3.0                3.143
# 161538          27.0         1.0                2.429
#
#         total_cases_per_million  new_cases_per_million  ...
# 161452                      NaN                  0.000  ...  \
# 161453                      NaN                  0.000  ...
# 161454                      NaN                  0.000  ...
# 161455                      NaN                  0.000  ...
# 161456                      NaN                  0.000  ...
# ...                         ...                    ...  ...
# 161534                   47.852                  3.123  ...
# 161535                   52.920                  5.068  ...
# 161536                   59.844                  6.924  ...
# 161537                   63.675                  3.830  ...
# 161538                   68.360                  4.685  ...
#
#         total_deaths_per_million  new_deaths_per_million
# 161452                       NaN                   0.000  \
# 161453                       NaN                   0.000
# 161454                       NaN                   0.000
# 161455                       NaN                   0.000
# 161456                       NaN                   0.000
# ...                          ...                     ...
# 161534                     0.471                   0.059
# 161535                     0.560                   0.088
# 161536                     0.678                   0.118
# 161537                     0.766                   0.088
# 161538                     0.796                   0.029
#
#         new_deaths_smoothed_per_million  reproduction_rate  icu_patients
# 161452                              NaN           1.044208           NaN  \
# 161453                              NaN           1.044208           NaN
# 161454                              NaN           1.044208           NaN
# 161455                              NaN           1.044208           NaN
# 161456                              NaN           1.044208           NaN
# ...                                 ...                ...           ...
# 161534                            0.059           1.540000          60.0
# 161535                            0.072           1.480000          71.0
# 161536                            0.084           1.390000          75.0
# 161537                            0.093           1.310000          94.0
# 161538                            0.072           1.250000          97.0
#
#         icu_patients_per_million  hosp_patients  hosp_patients_per_million
# 161452                       NaN            NaN                        NaN  \
# 161453                       NaN            NaN                        NaN
# 161454                       NaN            NaN                        NaN
# 161455                       NaN            NaN                        NaN
# 161456                       NaN            NaN                        NaN
# ...                          ...            ...                        ...
# 161534                     1.768         1229.0                     36.213
# 161535                     2.092         1347.0                     39.690
# 161536                     2.210         1422.0                     41.900
# 161537                     2.770         1491.0                     43.933
# 161538                     2.858         1540.0                     45.377
#
#         weekly_hosp_admissions  weekly_hosp_admissions_per_million
# 161452                     NaN                                 NaN
# 161453                     NaN                                 NaN
# 161454                     NaN                                 NaN
# 161455                     NaN                                 NaN
# 161456                     NaN                                 NaN
# ...                        ...                                 ...
# 161534                     NaN                                 NaN
# 161535                     NaN                                 NaN
# 161536                     NaN                                 NaN
# 161537                     NaN                                 NaN
# 161538                     NaN                                 NaN
#
# [87 rows x 21 columns]

# %% [markdown]
# Since weekly_hosp_admission cannot be determined, leaving the weekly_hosp_admission as emppty data to deal with uncertainty

# %%
#Locate the row of Missing Values
trace_missing_total_cases_per_million = pd.isnull(CovidDeathsNew['total_cases_per_million'])
CovidDeathsNew[trace_missing_total_cases_per_million]
# Out:
#              date  population  total_cases  new_cases  new_cases_smoothed
# 161452   3/1/2020    33938216          0.0        0.0                 0.0  \
# 161453   4/1/2020    33938216          0.0        0.0                 0.0
# 161454   5/1/2020    33938216          0.0        0.0                 0.0
# 161455   6/1/2020    33938216          0.0        0.0                 0.0
# 161456   7/1/2020    33938216          0.0        0.0                 0.0
# 161457   8/1/2020    33938216          0.0        0.0                 0.0
# 161458   9/1/2020    33938216          0.0        0.0                 0.0
# 161459  10/1/2020    33938216          0.0        0.0                 0.0
# 161460  11/1/2020    33938216          0.0        0.0                 0.0
# 161461  12/1/2020    33938216          0.0        0.0                 0.0
# 161462  13/1/2020    33938216          0.0        0.0                 0.0
# 161463  14/1/2020    33938216          0.0        0.0                 0.0
# 161464  15/1/2020    33938216          0.0        0.0                 0.0
# 161465  16/1/2020    33938216          0.0        0.0                 0.0
# 161466  17/1/2020    33938216          0.0        0.0                 0.0
# 161467  18/1/2020    33938216          0.0        0.0                 0.0
# 161468  19/1/2020    33938216          0.0        0.0                 0.0
# 161469  20/1/2020    33938216          0.0        0.0                 0.0
# 161470  21/1/2020    33938216          0.0        0.0                 0.0
# 161471  22/1/2020    33938216          0.0        0.0                 0.0
# 161472  23/1/2020    33938216          0.0        0.0                 0.0
# 161473  24/1/2020    33938216          0.0        0.0                 0.0
# 161474  25/1/2020    33938216          0.0        0.0                 0.0
#
#         total_deaths  new_deaths  new_deaths_smoothed
# 161452           0.0         0.0                  0.0  \
# 161453           0.0         0.0                  0.0
# 161454           0.0         0.0                  0.0
# 161455           0.0         0.0                  0.0
# 161456           0.0         0.0                  0.0
# 161457           0.0         0.0                  0.0
# 161458           0.0         0.0                  0.0
# 161459           0.0         0.0                  0.0
# 161460           0.0         0.0                  0.0
# 161461           0.0         0.0                  0.0
# 161462           0.0         0.0                  0.0
# 161463           0.0         0.0                  0.0
# 161464           0.0         0.0                  0.0
# 161465           0.0         0.0                  0.0
# 161466           0.0         0.0                  0.0
# 161467           0.0         0.0                  0.0
# 161468           0.0         0.0                  0.0
# 161469           0.0         0.0                  0.0
# 161470           0.0         0.0                  0.0
# 161471           0.0         0.0                  0.0
# 161472           0.0         0.0                  0.0
# 161473           0.0         0.0                  0.0
# 161474           0.0         0.0                  0.0
#
#         total_cases_per_million  new_cases_per_million  ...
# 161452                      NaN                    0.0  ...  \
# 161453                      NaN                    0.0  ...
# 161454                      NaN                    0.0  ...
# 161455                      NaN                    0.0  ...
# 161456                      NaN                    0.0  ...
# 161457                      NaN                    0.0  ...
# 161458                      NaN                    0.0  ...
# 161459                      NaN                    0.0  ...
# 161460                      NaN                    0.0  ...
# 161461                      NaN                    0.0  ...
# 161462                      NaN                    0.0  ...
# 161463                      NaN                    0.0  ...
# 161464                      NaN                    0.0  ...
# 161465                      NaN                    0.0  ...
# 161466                      NaN                    0.0  ...
# 161467                      NaN                    0.0  ...
# 161468                      NaN                    0.0  ...
# 161469                      NaN                    0.0  ...
# 161470                      NaN                    0.0  ...
# 161471                      NaN                    0.0  ...
# 161472                      NaN                    0.0  ...
# 161473                      NaN                    0.0  ...
# 161474                      NaN                    0.0  ...
#
#         total_deaths_per_million  new_deaths_per_million
# 161452                       NaN                     0.0  \
# 161453                       NaN                     0.0
# 161454                       NaN                     0.0
# 161455                       NaN                     0.0
# 161456                       NaN                     0.0
# 161457                       NaN                     0.0
# 161458                       NaN                     0.0
# 161459                       NaN                     0.0
# 161460                       NaN                     0.0
# 161461                       NaN                     0.0
# 161462                       NaN                     0.0
# 161463                       NaN                     0.0
# 161464                       NaN                     0.0
# 161465                       NaN                     0.0
# 161466                       NaN                     0.0
# 161467                       NaN                     0.0
# 161468                       NaN                     0.0
# 161469                       NaN                     0.0
# 161470                       NaN                     0.0
# 161471                       NaN                     0.0
# 161472                       NaN                     0.0
# 161473                       NaN                     0.0
# 161474                       NaN                     0.0
#
#         new_deaths_smoothed_per_million  reproduction_rate  icu_patients
# 161452                              NaN           1.044208           NaN  \
# 161453                              NaN           1.044208           NaN
# 161454                              NaN           1.044208           NaN
# 161455                              NaN           1.044208           NaN
# 161456                              NaN           1.044208           NaN
# 161457                              0.0           1.044208           NaN
# 161458                              0.0           1.044208           NaN
# 161459                              0.0           1.044208           NaN
# 161460                              0.0           1.044208           NaN
# 161461                              0.0           1.044208           NaN
# 161462                              0.0           1.044208           NaN
# 161463                              0.0           1.044208           NaN
# 161464                              0.0           1.044208           NaN
# 161465                              0.0           1.044208           NaN
# 161466                              0.0           1.044208           NaN
# 161467                              0.0           1.044208           NaN
# 161468                              0.0           1.044208           NaN
# 161469                              0.0           1.044208           NaN
# 161470                              0.0           1.044208           NaN
# 161471                              0.0           1.044208           NaN
# 161472                              0.0           1.044208           NaN
# 161473                              0.0           1.044208           NaN
# 161474                              0.0           1.044208           NaN
#
#         icu_patients_per_million  hosp_patients  hosp_patients_per_million
# 161452                       NaN            NaN                        NaN  \
# 161453                       NaN            NaN                        NaN
# 161454                       NaN            NaN                        NaN
# 161455                       NaN            NaN                        NaN
# 161456                       NaN            NaN                        NaN
# 161457                       NaN            NaN                        NaN
# 161458                       NaN            NaN                        NaN
# 161459                       NaN            NaN                        NaN
# 161460                       NaN            NaN                        NaN
# 161461                       NaN            NaN                        NaN
# 161462                       NaN            NaN                        NaN
# 161463                       NaN            NaN                        NaN
# 161464                       NaN            NaN                        NaN
# 161465                       NaN            NaN                        NaN
# 161466                       NaN            NaN                        NaN
# 161467                       NaN            NaN                        NaN
# 161468                       NaN            NaN                        NaN
# 161469                       NaN            NaN                        NaN
# 161470                       NaN            NaN                        NaN
# 161471                       NaN            NaN                        NaN
# 161472                       NaN            NaN                        NaN
# 161473                       NaN            NaN                        NaN
# 161474                       NaN            NaN                        NaN
#
#         weekly_hosp_admissions  weekly_hosp_admissions_per_million
# 161452                     NaN                                 NaN
# 161453                     NaN                                 NaN
# 161454                     NaN                                 NaN
# 161455                     NaN                                 NaN
# 161456                     NaN                                 NaN
# 161457                     NaN                                 NaN
# 161458                     NaN                                 NaN
# 161459                     NaN                                 NaN
# 161460                     NaN                                 NaN
# 161461                     NaN                                 NaN
# 161462                     NaN                                 NaN
# 161463                     NaN                                 NaN
# 161464                     NaN                                 NaN
# 161465                     NaN                                 NaN
# 161466                     NaN                                 NaN
# 161467                     NaN                                 NaN
# 161468                     NaN                                 NaN
# 161469                     NaN                                 NaN
# 161470                     NaN                                 NaN
# 161471                     NaN                                 NaN
# 161472                     NaN                                 NaN
# 161473                     NaN                                 NaN
# 161474                     NaN                                 NaN
#
# [23 rows x 21 columns]

# %%
#Replace with zero
CovidDeathsNew.total_cases_per_million = CovidDeathsNew.total_cases_per_million.fillna(0) #By Column

# %%
CovidDeathsNew.isnull().sum()
# Out:
# date                                   0
# population                             0
# total_cases                            0
# new_cases                              0
# new_cases_smoothed                     0
# total_deaths                           0
# new_deaths                             0
# new_deaths_smoothed                    0
# total_cases_per_million                0
# new_cases_per_million                  2
# new_cases_smoothed_per_million         7
# total_deaths_per_million              74
# new_deaths_per_million                 0
# new_deaths_smoothed_per_million        5
# reproduction_rate                      0
# icu_patients                          81
# icu_patients_per_million              81
# hosp_patients                         81
# hosp_patients_per_million             81
# weekly_hosp_admissions                87
# weekly_hosp_admissions_per_million    87
# dtype: int64

# %%
#Locate the row of Missing Values
trace_missing_new_cases_per_million = pd.isnull(CovidDeathsNew['new_cases_per_million'])
CovidDeathsNew[trace_missing_new_cases_per_million]
# Out:
#             date  population  total_cases  new_cases  new_cases_smoothed
# 162667  2/5/2023    33938216    5071840.0        0.0                 0.0  \
# 162668  3/5/2023    33938216    5071840.0        0.0                 0.0
#
#         total_deaths  new_deaths  new_deaths_smoothed
# 162667       37020.0         0.0                1.286  \
# 162668       37020.0         0.0                1.286
#
#         total_cases_per_million  new_cases_per_million  ...
# 162667                149443.33                    NaN  ...  \
# 162668                149443.33                    NaN  ...
#
#         total_deaths_per_million  new_deaths_per_million
# 162667                  1090.806                     0.0  \
# 162668                  1090.806                     0.0
#
#         new_deaths_smoothed_per_million  reproduction_rate  icu_patients
# 162667                            0.038           1.044208          41.0  \
# 162668                            0.038           1.044208          44.0
#
#         icu_patients_per_million  hosp_patients  hosp_patients_per_million
# 162667                     1.208          725.0                     21.362  \
# 162668                     1.296          772.0                     22.747
#
#         weekly_hosp_admissions  weekly_hosp_admissions_per_million
# 162667                  1538.0                              45.318
# 162668                  1593.0                              46.938
#
# [2 rows x 21 columns]

# %%
#Replace with zero
CovidDeathsNew.new_cases_per_million = CovidDeathsNew.new_cases_per_million.fillna(0) #By Column

# %%
CovidDeathsNew.isnull().sum()
# Out:
# date                                   0
# population                             0
# total_cases                            0
# new_cases                              0
# new_cases_smoothed                     0
# total_deaths                           0
# new_deaths                             0
# new_deaths_smoothed                    0
# total_cases_per_million                0
# new_cases_per_million                  0
# new_cases_smoothed_per_million         7
# total_deaths_per_million              74
# new_deaths_per_million                 0
# new_deaths_smoothed_per_million        5
# reproduction_rate                      0
# icu_patients                          81
# icu_patients_per_million              81
# hosp_patients                         81
# hosp_patients_per_million             81
# weekly_hosp_admissions                87
# weekly_hosp_admissions_per_million    87
# dtype: int64

# %%
#Locate the row of Missing Values
trace_missing_new_cases_smoothed_per_million = pd.isnull(CovidDeathsNew['new_cases_smoothed_per_million'])
CovidDeathsNew[trace_missing_new_cases_smoothed_per_million]
# Out:
#             date  population  total_cases  new_cases  new_cases_smoothed
# 161452  3/1/2020    33938216          0.0        0.0                 0.0  \
# 161453  4/1/2020    33938216          0.0        0.0                 0.0
# 161454  5/1/2020    33938216          0.0        0.0                 0.0
# 161455  6/1/2020    33938216          0.0        0.0                 0.0
# 161456  7/1/2020    33938216          0.0        0.0                 0.0
# 162667  2/5/2023    33938216    5071840.0        0.0                 0.0
# 162668  3/5/2023    33938216    5071840.0        0.0                 0.0
#
#         total_deaths  new_deaths  new_deaths_smoothed
# 161452           0.0         0.0                0.000  \
# 161453           0.0         0.0                0.000
# 161454           0.0         0.0                0.000
# 161455           0.0         0.0                0.000
# 161456           0.0         0.0                0.000
# 162667       37020.0         0.0                1.286
# 162668       37020.0         0.0                1.286
#
#         total_cases_per_million  new_cases_per_million  ...
# 161452                     0.00                    0.0  ...  \
# 161453                     0.00                    0.0  ...
# 161454                     0.00                    0.0  ...
# 161455                     0.00                    0.0  ...
# 161456                     0.00                    0.0  ...
# 162667                149443.33                    0.0  ...
# 162668                149443.33                    0.0  ...
#
#         total_deaths_per_million  new_deaths_per_million
# 161452                       NaN                     0.0  \
# 161453                       NaN                     0.0
# 161454                       NaN                     0.0
# 161455                       NaN                     0.0
# 161456                       NaN                     0.0
# 162667                  1090.806                     0.0
# 162668                  1090.806                     0.0
#
#         new_deaths_smoothed_per_million  reproduction_rate  icu_patients
# 161452                              NaN           1.044208           NaN  \
# 161453                              NaN           1.044208           NaN
# 161454                              NaN           1.044208           NaN
# 161455                              NaN           1.044208           NaN
# 161456                              NaN           1.044208           NaN
# 162667                            0.038           1.044208          41.0
# 162668                            0.038           1.044208          44.0
#
#         icu_patients_per_million  hosp_patients  hosp_patients_per_million
# 161452                       NaN            NaN                        NaN  \
# 161453                       NaN            NaN                        NaN
# 161454                       NaN            NaN                        NaN
# 161455                       NaN            NaN                        NaN
# 161456                       NaN            NaN                        NaN
# 162667                     1.208          725.0                     21.362
# 162668                     1.296          772.0                     22.747
#
#         weekly_hosp_admissions  weekly_hosp_admissions_per_million
# 161452                     NaN                                 NaN
# 161453                     NaN                                 NaN
# 161454                     NaN                                 NaN
# 161455                     NaN                                 NaN
# 161456                     NaN                                 NaN
# 162667                  1538.0                              45.318
# 162668                  1593.0                              46.938
#
# [7 rows x 21 columns]

# %%
#Locate the row of Missing Values
trace_missing_total_deaths_per_million = pd.isnull(CovidDeathsNew['total_deaths_per_million'])
CovidDeathsNew[trace_missing_total_deaths_per_million]
# Out:
#              date  population  total_cases  new_cases  new_cases_smoothed
# 161452   3/1/2020    33938216          0.0        0.0               0.000  \
# 161453   4/1/2020    33938216          0.0        0.0               0.000
# 161454   5/1/2020    33938216          0.0        0.0               0.000
# 161455   6/1/2020    33938216          0.0        0.0               0.000
# 161456   7/1/2020    33938216          0.0        0.0               0.000
# ...           ...         ...          ...        ...                 ...
# 161521  12/3/2020    33938216        149.0       32.0              14.143
# 161522  13/3/2020    33938216        158.0        9.0              14.714
# 161523  14/3/2020    33938216        197.0       39.0              16.286
# 161524  15/3/2020    33938216        238.0       41.0              20.714
# 161525  16/3/2020    33938216        428.0      190.0              47.000
#
#         total_deaths  new_deaths  new_deaths_smoothed
# 161452           0.0         0.0                  0.0  \
# 161453           0.0         0.0                  0.0
# 161454           0.0         0.0                  0.0
# 161455           0.0         0.0                  0.0
# 161456           0.0         0.0                  0.0
# ...              ...         ...                  ...
# 161521           0.0         0.0                  0.0
# 161522           0.0         0.0                  0.0
# 161523           0.0         0.0                  0.0
# 161524           0.0         0.0                  0.0
# 161525           0.0         0.0                  0.0
#
#         total_cases_per_million  new_cases_per_million  ...
# 161452                    0.000                  0.000  ...  \
# 161453                    0.000                  0.000  ...
# 161454                    0.000                  0.000  ...
# 161455                    0.000                  0.000  ...
# 161456                    0.000                  0.000  ...
# ...                         ...                    ...  ...
# 161521                    4.390                  0.943  ...
# 161522                    4.656                  0.265  ...
# 161523                    5.805                  1.149  ...
# 161524                    7.013                  1.208  ...
# 161525                   12.611                  5.598  ...
#
#         total_deaths_per_million  new_deaths_per_million
# 161452                       NaN                     0.0  \
# 161453                       NaN                     0.0
# 161454                       NaN                     0.0
# 161455                       NaN                     0.0
# 161456                       NaN                     0.0
# ...                          ...                     ...
# 161521                       NaN                     0.0
# 161522                       NaN                     0.0
# 161523                       NaN                     0.0
# 161524                       NaN                     0.0
# 161525                       NaN                     0.0
#
#         new_deaths_smoothed_per_million  reproduction_rate  icu_patients
# 161452                              NaN           1.044208           NaN  \
# 161453                              NaN           1.044208           NaN
# 161454                              NaN           1.044208           NaN
# 161455                              NaN           1.044208           NaN
# 161456                              NaN           1.044208           NaN
# ...                                 ...                ...           ...
# 161521                              0.0           2.160000           NaN
# 161522                              0.0           2.300000           NaN
# 161523                              0.0           2.420000           NaN
# 161524                              0.0           2.540000           NaN
# 161525                              0.0           2.430000           NaN
#
#         icu_patients_per_million  hosp_patients  hosp_patients_per_million
# 161452                       NaN            NaN                        NaN  \
# 161453                       NaN            NaN                        NaN
# 161454                       NaN            NaN                        NaN
# 161455                       NaN            NaN                        NaN
# 161456                       NaN            NaN                        NaN
# ...                          ...            ...                        ...
# 161521                       NaN            NaN                        NaN
# 161522                       NaN            NaN                        NaN
# 161523                       NaN            NaN                        NaN
# 161524                       NaN            NaN                        NaN
# 161525                       NaN            NaN                        NaN
#
#         weekly_hosp_admissions  weekly_hosp_admissions_per_million
# 161452                     NaN                                 NaN
# 161453                     NaN                                 NaN
# 161454                     NaN                                 NaN
# 161455                     NaN                                 NaN
# 161456                     NaN                                 NaN
# ...                        ...                                 ...
# 161521                     NaN                                 NaN
# 161522                     NaN                                 NaN
# 161523                     NaN                                 NaN
# 161524                     NaN                                 NaN
# 161525                     NaN                                 NaN
#
# [74 rows x 21 columns]

# %%
#Locate the row of Missing Values
trace_missing_new_deaths_smoothed_per_million = pd.isnull(CovidDeathsNew['new_deaths_smoothed_per_million'])
CovidDeathsNew[trace_missing_new_deaths_smoothed_per_million]
# Out:
#             date  population  total_cases  new_cases  new_cases_smoothed
# 161452  3/1/2020    33938216          0.0        0.0                 0.0  \
# 161453  4/1/2020    33938216          0.0        0.0                 0.0
# 161454  5/1/2020    33938216          0.0        0.0                 0.0
# 161455  6/1/2020    33938216          0.0        0.0                 0.0
# 161456  7/1/2020    33938216          0.0        0.0                 0.0
#
#         total_deaths  new_deaths  new_deaths_smoothed
# 161452           0.0         0.0                  0.0  \
# 161453           0.0         0.0                  0.0
# 161454           0.0         0.0                  0.0
# 161455           0.0         0.0                  0.0
# 161456           0.0         0.0                  0.0
#
#         total_cases_per_million  new_cases_per_million  ...
# 161452                      0.0                    0.0  ...  \
# 161453                      0.0                    0.0  ...
# 161454                      0.0                    0.0  ...
# 161455                      0.0                    0.0  ...
# 161456                      0.0                    0.0  ...
#
#         total_deaths_per_million  new_deaths_per_million
# 161452                       NaN                     0.0  \
# 161453                       NaN                     0.0
# 161454                       NaN                     0.0
# 161455                       NaN                     0.0
# 161456                       NaN                     0.0
#
#         new_deaths_smoothed_per_million  reproduction_rate  icu_patients
# 161452                              NaN           1.044208           NaN  \
# 161453                              NaN           1.044208           NaN
# 161454                              NaN           1.044208           NaN
# 161455                              NaN           1.044208           NaN
# 161456                              NaN           1.044208           NaN
#
#         icu_patients_per_million  hosp_patients  hosp_patients_per_million
# 161452                       NaN            NaN                        NaN  \
# 161453                       NaN            NaN                        NaN
# 161454                       NaN            NaN                        NaN
# 161455                       NaN            NaN                        NaN
# 161456                       NaN            NaN                        NaN
#
#         weekly_hosp_admissions  weekly_hosp_admissions_per_million
# 161452                     NaN                                 NaN
# 161453                     NaN                                 NaN
# 161454                     NaN                                 NaN
# 161455                     NaN                                 NaN
# 161456                     NaN                                 NaN
#
# [5 rows x 21 columns]

# %%
#Locate the row of Missing Values
trace_missing_icu_patients = pd.isnull(CovidDeathsNew['icu_patients'])
CovidDeathsNew[trace_missing_icu_patients]
# Out:
#              date  population  total_cases  new_cases  new_cases_smoothed
# 161452   3/1/2020    33938216          0.0        0.0               0.000  \
# 161453   4/1/2020    33938216          0.0        0.0               0.000
# 161454   5/1/2020    33938216          0.0        0.0               0.000
# 161455   6/1/2020    33938216          0.0        0.0               0.000
# 161456   7/1/2020    33938216          0.0        0.0               0.000
# ...           ...         ...          ...        ...                 ...
# 161528  19/3/2020    33938216        790.0      117.0              91.571
# 161529  20/3/2020    33938216        900.0      110.0             106.000
# 161530  21/3/2020    33938216       1030.0      130.0             119.000
# 161531  22/3/2020    33938216       1183.0      153.0             135.000
# 161532  23/3/2020    33938216       1306.0      123.0             125.429
#
#         total_deaths  new_deaths  new_deaths_smoothed
# 161452           0.0         0.0                0.000  \
# 161453           0.0         0.0                0.000
# 161454           0.0         0.0                0.000
# 161455           0.0         0.0                0.000
# 161456           0.0         0.0                0.000
# ...              ...         ...                  ...
# 161528           2.0         0.0                0.286
# 161529           3.0         1.0                0.429
# 161530           4.0         1.0                0.571
# 161531          10.0         6.0                1.429
# 161532          10.0         0.0                1.429
#
#         total_cases_per_million  new_cases_per_million  ...
# 161452                    0.000                  0.000  ...  \
# 161453                    0.000                  0.000  ...
# 161454                    0.000                  0.000  ...
# 161455                    0.000                  0.000  ...
# 161456                    0.000                  0.000  ...
# ...                         ...                    ...  ...
# 161528                   23.278                  3.447  ...
# 161529                   26.519                  3.241  ...
# 161530                   30.349                  3.830  ...
# 161531                   34.857                  4.508  ...
# 161532                   38.482                  3.624  ...
#
#         total_deaths_per_million  new_deaths_per_million
# 161452                       NaN                   0.000  \
# 161453                       NaN                   0.000
# 161454                       NaN                   0.000
# 161455                       NaN                   0.000
# 161456                       NaN                   0.000
# ...                          ...                     ...
# 161528                     0.059                   0.000
# 161529                     0.088                   0.029
# 161530                     0.118                   0.029
# 161531                     0.295                   0.177
# 161532                     0.295                   0.000
#
#         new_deaths_smoothed_per_million  reproduction_rate  icu_patients
# 161452                              NaN           1.044208           NaN  \
# 161453                              NaN           1.044208           NaN
# 161454                              NaN           1.044208           NaN
# 161455                              NaN           1.044208           NaN
# 161456                              NaN           1.044208           NaN
# ...                                 ...                ...           ...
# 161528                            0.008           2.030000           NaN
# 161529                            0.013           1.910000           NaN
# 161530                            0.017           1.810000           NaN
# 161531                            0.042           1.690000           NaN
# 161532                            0.042           1.650000           NaN
#
#         icu_patients_per_million  hosp_patients  hosp_patients_per_million
# 161452                       NaN            NaN                        NaN  \
# 161453                       NaN            NaN                        NaN
# 161454                       NaN            NaN                        NaN
# 161455                       NaN            NaN                        NaN
# 161456                       NaN            NaN                        NaN
# ...                          ...            ...                        ...
# 161528                       NaN            NaN                        NaN
# 161529                       NaN            NaN                        NaN
# 161530                       NaN            NaN                        NaN
# 161531                       NaN            NaN                        NaN
# 161532                       NaN            NaN                        NaN
#
#         weekly_hosp_admissions  weekly_hosp_admissions_per_million
# 161452                     NaN                                 NaN
# 161453                     NaN                                 NaN
# 161454                     NaN                                 NaN
# 161455                     NaN                                 NaN
# 161456                     NaN                                 NaN
# ...                        ...                                 ...
# 161528                     NaN                                 NaN
# 161529                     NaN                                 NaN
# 161530                     NaN                                 NaN
# 161531                     NaN                                 NaN
# 161532                     NaN                                 NaN
#
# [81 rows x 21 columns]

# %%
#Replace with zero
columns_to_fill = [
    'new_cases_smoothed_per_million',
    'total_deaths_per_million',
    'new_deaths_smoothed_per_million',
    'icu_patients',
    'icu_patients_per_million',
    'hosp_patients_per_million',
    'hosp_patients'
]

# Fill missing values with 0 for the specified columns
CovidDeathsNew[columns_to_fill] = CovidDeathsNew[columns_to_fill].fillna(0)

# %%
CovidDeathsNew.isnull().sum()
# Out:
# date                                   0
# population                             0
# total_cases                            0
# new_cases                              0
# new_cases_smoothed                     0
# total_deaths                           0
# new_deaths                             0
# new_deaths_smoothed                    0
# total_cases_per_million                0
# new_cases_per_million                  0
# new_cases_smoothed_per_million         0
# total_deaths_per_million               0
# new_deaths_per_million                 0
# new_deaths_smoothed_per_million        0
# reproduction_rate                      0
# icu_patients                           0
# icu_patients_per_million               0
# hosp_patients                          0
# hosp_patients_per_million              0
# weekly_hosp_admissions                87
# weekly_hosp_admissions_per_million    87
# dtype: int64

# %%
CovidDeathsNew = CovidDeathsNew.reset_index(drop = True)

# %%
CovidDeathsNew
# Out:
#            date  population  total_cases  new_cases  new_cases_smoothed
# 0      3/1/2020    33938216          0.0        0.0               0.000  \
# 1      4/1/2020    33938216          0.0        0.0               0.000
# 2      5/1/2020    33938216          0.0        0.0               0.000
# 3      6/1/2020    33938216          0.0        0.0               0.000
# 4      7/1/2020    33938216          0.0        0.0               0.000
# ...         ...         ...          ...        ...                 ...
# 1212  29/4/2023    33938216    5066877.0        0.0             688.143
# 1213  30/4/2023    33938216    5071694.0     4817.0             688.143
# 1214   1/5/2023    33938216    5071840.0      146.0             709.000
# 1215   2/5/2023    33938216    5071840.0        0.0               0.000
# 1216   3/5/2023    33938216    5071840.0        0.0               0.000
#
#       total_deaths  new_deaths  new_deaths_smoothed  total_cases_per_million
# 0              0.0         0.0                0.000                    0.000  \
# 1              0.0         0.0                0.000                    0.000
# 2              0.0         0.0                0.000                    0.000
# 3              0.0         0.0                0.000                    0.000
# 4              0.0         0.0                0.000                    0.000
# ...            ...         ...                  ...                      ...
# 1212       37011.0         0.0                1.571               149297.093
# 1213       37020.0         9.0                2.857               149439.028
# 1214       37020.0         0.0                1.286               149443.330
# 1215       37020.0         0.0                1.286               149443.330
# 1216       37020.0         0.0                1.286               149443.330
#
#       new_cases_per_million  ...  total_deaths_per_million
# 0                     0.000  ...                     0.000  \
# 1                     0.000  ...                     0.000
# 2                     0.000  ...                     0.000
# 3                     0.000  ...                     0.000
# 4                     0.000  ...                     0.000
# ...                     ...  ...                       ...
# 1212                  0.000  ...                  1090.541
# 1213                141.934  ...                  1090.806
# 1214                  4.302  ...                  1090.806
# 1215                  0.000  ...                  1090.806
# 1216                  0.000  ...                  1090.806
#
#       new_deaths_per_million  new_deaths_smoothed_per_million
# 0                      0.000                            0.000  \
# 1                      0.000                            0.000
# 2                      0.000                            0.000
# 3                      0.000                            0.000
# 4                      0.000                            0.000
# ...                      ...                              ...
# 1212                   0.000                            0.046
# 1213                   0.265                            0.084
# 1214                   0.000                            0.038
# 1215                   0.000                            0.038
# 1216                   0.000                            0.038
#
#       reproduction_rate  icu_patients  icu_patients_per_million
# 0              1.044208           0.0                     0.000  \
# 1              1.044208           0.0                     0.000
# 2              1.044208           0.0                     0.000
# 3              1.044208           0.0                     0.000
# 4              1.044208           0.0                     0.000
# ...                 ...           ...                       ...
# 1212           1.044208          29.0                     0.854
# 1213           1.044208          64.0                     1.886
# 1214           1.044208          41.0                     1.208
# 1215           1.044208          41.0                     1.208
# 1216           1.044208          44.0                     1.296
#
#       hosp_patients  hosp_patients_per_million  weekly_hosp_admissions
# 0               0.0                      0.000                     NaN  \
# 1               0.0                      0.000                     NaN
# 2               0.0                      0.000                     NaN
# 3               0.0                      0.000                     NaN
# 4               0.0                      0.000                     NaN
# ...             ...                        ...                     ...
# 1212          673.0                     19.830                  1194.0
# 1213          737.0                     21.716                  1345.0
# 1214          767.0                     22.600                  1462.0
# 1215          725.0                     21.362                  1538.0
# 1216          772.0                     22.747                  1593.0
#
#       weekly_hosp_admissions_per_million
# 0                                    NaN
# 1                                    NaN
# 2                                    NaN
# 3                                    NaN
# 4                                    NaN
# ...                                  ...
# 1212                              35.182
# 1213                              39.631
# 1214                              43.078
# 1215                              45.318
# 1216                              46.938
#
# [1217 rows x 21 columns]

# %% [markdown]
# Checking duplicate row

# %%
CovidDeathsNew[CovidDeathsNew.duplicated(keep=False)] #use duplicate function
# Out:
# Empty DataFrame
# Columns: [date, population, total_cases, new_cases, new_cases_smoothed, total_deaths, new_deaths, new_deaths_smoothed, total_cases_per_million, new_cases_per_million, new_cases_smoothed_per_million, total_deaths_per_million, new_deaths_per_million, new_deaths_smoothed_per_million, reproduction_rate, icu_patients, icu_patients_per_million, hosp_patients, hosp_patients_per_million, weekly_hosp_admissions, weekly_hosp_admissions_per_million]
# Index: []
#
# [0 rows x 21 columns]

# %% [markdown]
# # Feature Selection and correlation

# %%
CovidDeathsNew.to_csv ('CovidDeathsClean.csv', index=None)
CovidDeathsClean = pd.read_csv('CovidDeathsClean.csv')

# %%
profile = pp.ProfileReport(CovidDeathsClean)
profile.to_file("CovidDeathsClean.html")
# Out:
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
# Generate report structure:   0%|          | 0/1 [00:00<?, ?it/s]
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
# Heatmap Correlation
plt.figure(figsize=(10,10))
CovidDeathsClean2 = CovidDeathsClean.iloc[:, 1:]
sns.heatmap(CovidDeathsClean2.corr(), annot=True, cmap='coolwarm')
#Annot is to add the annotation from correlation matrix
#cmap - color map

# To select only features with <-0.2 and >0.2
# Out:
# <Axes: >

# %%
#choose one diagnosis only since the outcome will be same
CovidDeathsClean3 = CovidDeathsClean2.loc[:, ~CovidDeathsClean2.corrwith(CovidDeathsClean2['total_deaths']).between(-.2, .2)]
len(CovidDeathsClean3.columns)
# Out:
# 10

# %% [markdown]
# # Checking for outlier

# %%
# Plotting Distribution Graph
import matplotlib.pyplot as plt
import seaborn as sns  # Optional, for better styling

columns_to_plot = CovidDeathsClean3.columns

# Set up subplots
fig, axes = plt.subplots(nrows=len(columns_to_plot), ncols=1, figsize=(8, 6*len(columns_to_plot)))

# Use seaborn for better styling (optional)
sns.set(style="whitegrid")

# Create boxplots for each column
for i, column_name in enumerate(columns_to_plot):
    sns.boxplot(x=CovidDeathsNew[column_name], ax=axes[i])
    axes[i].set_title(f'Boxplot for {column_name}')
    axes[i].set_xlabel(column_name)

# Adjust spacing between subplots
plt.tight_layout()

# Show the plots
plt.show()

# %% [markdown]
# Some attributes have outliers but there are natural outlier which deleteing them will affect the model. So, we go through with outliers first.

# %%
#Removing Outliers using Quantile Method. Get the 99th percentile and keep the data below it

#q = data_clean['Price'].quantile(0.99)
#data_clean = data_clean[data_clean['Price']<q]
#data_clean.describe(include='all')

# %%
CovidDeathsClean3
# Out:
#       population  total_cases  new_cases  new_cases_smoothed  total_deaths
# 0       33938216          0.0        0.0               0.000           0.0  \
# 1       33938216          0.0        0.0               0.000           0.0
# 2       33938216          0.0        0.0               0.000           0.0
# 3       33938216          0.0        0.0               0.000           0.0
# 4       33938216          0.0        0.0               0.000           0.0
# ...          ...          ...        ...                 ...           ...
# 1212    33938216    5066877.0        0.0             688.143       37011.0
# 1213    33938216    5071694.0     4817.0             688.143       37020.0
# 1214    33938216    5071840.0      146.0             709.000       37020.0
# 1215    33938216    5071840.0        0.0               0.000       37020.0
# 1216    33938216    5071840.0        0.0               0.000       37020.0
#
#       total_cases_per_million  new_cases_per_million
# 0                       0.000                  0.000  \
# 1                       0.000                  0.000
# 2                       0.000                  0.000
# 3                       0.000                  0.000
# 4                       0.000                  0.000
# ...                       ...                    ...
# 1212               149297.093                  0.000
# 1213               149439.028                141.934
# 1214               149443.330                  4.302
# 1215               149443.330                  0.000
# 1216               149443.330                  0.000
#
#       new_cases_smoothed_per_million  total_deaths_per_million
# 0                              0.000                     0.000  \
# 1                              0.000                     0.000
# 2                              0.000                     0.000
# 3                              0.000                     0.000
# 4                              0.000                     0.000
# ...                              ...                       ...
# 1212                          20.276                  1090.541
# 1213                          20.276                  1090.806
# 1214                          20.891                  1090.806
# 1215                           0.000                  1090.806
# 1216                           0.000                  1090.806
#
#       reproduction_rate
# 0              1.044208
# 1              1.044208
# 2              1.044208
# 3              1.044208
# 4              1.044208
# ...                 ...
# 1212           1.044208
# 1213           1.044208
# 1214           1.044208
# 1215           1.044208
# 1216           1.044208
#
# [1217 rows x 10 columns]

# %% [markdown]
# # Data Normalization

# %%
X_attribute = ['population', 'total_cases', 'new_cases', 'new_cases_smoothed',
               'total_cases_per_million', 'new_cases_per_million',
               'new_cases_smoothed_per_million', 'total_deaths_per_million',
               'reproduction_rate']

X = CovidDeathsClean3.loc[:, X_attribute].values
y = CovidDeathsClean3.loc[:, 'total_deaths'].values

original_shape_x = X.shape
original_shape_y = y.shape

# %%
print(X.shape)
print(y.shape)
# Out:
# (1217, 9)
# (1217,)

# %%
import numpy as np
from sklearn.preprocessing import MinMaxScaler

X = X.reshape(-1, 1)  # Reshape X to have one column
y = y.reshape(-1, 1)  # Reshape y to have one column

scaler_x = MinMaxScaler()
scaler_y = MinMaxScaler()


# Fit and transform X and Y
normalized_x = scaler_x.fit_transform(X)
normalized_y = scaler_y.fit_transform(y)

print("Normalized X shape:", normalized_x.shape)
print("Normalized Y shape:", normalized_y.shape)
# Out:
# Normalized X shape: (10953, 1)
# Normalized Y shape: (1217, 1)

# %%
normalized_x = X.reshape(original_shape_x)
normalized_y = y.reshape(original_shape_y)
print("Normalized X shape:", normalized_x.shape)
print("Normalized Y shape:", normalized_y.shape)
print("Normalized X:", normalized_x)
print("Normalized Y:", normalized_y)
# Out:
# Normalized X shape: (1217, 9)
# Normalized Y shape: (1217,)
# Normalized X: [[3.39382160e+07 0.00000000e+00 0.00000000e+00 ... 0.00000000e+00
#   0.00000000e+00 1.04420797e+00]
#  [3.39382160e+07 0.00000000e+00 0.00000000e+00 ... 0.00000000e+00
#   0.00000000e+00 1.04420797e+00]
#  [3.39382160e+07 0.00000000e+00 0.00000000e+00 ... 0.00000000e+00
#   0.00000000e+00 1.04420797e+00]
#  ...
#  [3.39382160e+07 5.07184000e+06 1.46000000e+02 ... 2.08910000e+01
#   1.09080600e+03 1.04420797e+00]
#  [3.39382160e+07 5.07184000e+06 0.00000000e+00 ... 0.00000000e+00
#   1.09080600e+03 1.04420797e+00]
#  [3.39382160e+07 5.07184000e+06 0.00000000e+00 ... 0.00000000e+00
#   1.09080600e+03 1.04420797e+00]]
# Normalized Y: [    0.     0.     0. ... 37020. 37020. 37020.]

# %% [markdown]
# # Data Partitioning

# %%
# data partitioning (80:20) Training =80%, Testing =20%

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(normalized_x, normalized_y, test_size = 0.2, random_state=42) #random_state=0, Controls the shuffling applied to the data before applying the split. Pass an int for reproducible output across multiple function calls

# %%
X_train
# Out:
# array([[3.39382160e+07, 3.17717000e+05, 1.44800000e+03, ...,
#         4.98260000e+01, 3.49460000e+01, 8.00000000e-01],
#        [3.39382160e+07, 1.28130000e+04, 4.32000000e+02, ...,
#         7.48800000e+00, 4.03700000e+00, 1.84000000e+00],
#        [3.39382160e+07, 2.73524100e+06, 3.52800000e+03, ...,
#         9.88220000e+01, 9.22500000e+02, 8.80000000e-01],
#        ...,
#        [3.39382160e+07, 5.03817000e+06, 1.75000000e+02, ...,
#         7.69500000e+00, 1.08856600e+03, 1.04420797e+00],
#        [3.39382160e+07, 4.47047100e+06, 3.41000000e+03, ...,
#         6.88560000e+01, 1.04902400e+03, 9.10000000e-01],
#        [3.39382160e+07, 5.03724200e+06, 3.24000000e+02, ...,
#         7.85000000e+00, 1.08850700e+03, 1.04420797e+00]])

# %% [markdown]
# # Develop Multiple Linear Regression model

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred=regressor.predict(X_test)
y_pred
# Out:
# array([ 4.94398313e+03,  1.28013549e+02,  1.37529842e-04,  3.63869936e+04,
#         1.09609908e+04,  2.81993412e+02,  2.82340163e+04,  3.70110154e+04,
#         1.24009915e+02,  1.16001438e+02,  6.50300198e+03,  9.82987761e+02,
#         3.63849927e+04,  1.69999868e+03,  3.67130064e+04,  3.53599022e+03,
#         5.10800689e+03,  5.76800223e+03,  1.15899027e+03,  1.12101371e+03,
#         3.17229999e+04,  1.28798862e+03,  3.69569866e+04,  1.13000775e+03,
#         2.36006606e+02,  3.69080136e+04,  4.31998770e+02,  2.78580145e+04,
#         3.70110154e+04,  3.70110154e+04,  4.34799456e+03,  8.80022678e+01,
#         1.21800906e+03,  3.69669991e+04,  3.57319861e+04,  4.00126652e+00,
#         3.68409863e+04,  3.10730160e+04,  1.99876254e+00,  3.20989976e+04,
#        -5.33060721e-04,  3.69080141e+04,  3.56120158e+04,  9.60116855e+01,
#         3.65229851e+04,  1.33001585e+02,  1.05099872e+03,  1.72199091e+03,
#         2.71909949e+04,  5.20985437e+02,  3.18089988e+04,  1.24994696e+02,
#         1.22008132e+02,  3.08310030e+04,  1.34799871e+04,  1.11620057e+04,
#         2.29014164e+02,  3.13011420e+02,  1.25099994e+04,  1.40136818e+01,
#         3.90798529e+03,  3.20649899e+04,  4.30981790e-04,  1.82200685e+03,
#         2.94859958e+04,  9.65001014e+02,  3.57350077e+04,  3.93004492e+02,
#         3.58620035e+04,  3.57650084e+04,  4.55009629e+02,  3.69999868e+04,
#        -3.38262915e-03,  3.57460025e+04, -2.75253285e-05,  7.59888443e+01,
#         3.69139857e+04,  6.31352055e-04,  3.59139960e+04,  3.58479878e+04,
#         3.45015113e+02,  3.69190095e+04,  3.68530015e+04,  1.24993213e+02,
#         2.21004917e+02,  3.62989929e+04,  3.59319847e+04,  1.24994475e+02,
#         3.20000020e+04,  3.59950071e+04,  3.69300053e+04, -3.98606047e-04,
#         3.26340037e+04,  3.56600058e+04,  3.57760037e+04,  3.57950071e+04,
#         3.69669980e+04,  8.89871778e+01,  2.04189961e+04,  1.05005664e+02,
#        -3.98606047e-04,  3.62850104e+04,  3.60799876e+04,  1.07990936e+02,
#        -1.44030342e-03,  2.70138629e+01,  2.45649911e+04,  3.58279955e+04,
#         1.37004552e+02,  3.69790116e+04,  1.34500384e+03,  1.20990396e+02,
#         3.65739937e+04,  3.23099926e+04,  1.27840165e+04,  3.62910170e+04,
#         3.32279910e+04,  8.08984106e+02,  3.62490015e+04,  3.56380124e+04,
#         3.15910164e+04,  3.57079929e+04,  3.67629986e+04,  3.11349888e+04,
#         3.64230031e+04,  3.67690045e+04,  1.14100405e+03,  4.47699311e+03,
#         7.71799010e+03,  4.55400044e+03,  3.02800156e+04,  5.58995061e+02,
#         1.67007228e+02,  3.29419931e+04,  3.19520143e+04,  1.24993921e+02,
#         4.38991433e+02,  1.55500147e+04,  3.68659987e+04,  1.15301747e+03,
#         1.07490120e+04,  3.54909934e+04,  3.69669986e+04,  3.63909984e+04,
#         3.10439993e+04,  1.33002414e+02,  1.22991161e+02,  1.20991289e+02,
#         3.69790116e+04,  1.15015020e+02,  3.18179931e+04,  3.59849961e+04,
#         3.19019908e+04,  3.60199839e+04,  3.68509980e+04,  3.10919884e+04,
#         3.69819981e+04,  2.07110003e+04,  2.37439918e+04,  7.45994478e+02,
#         3.62700101e+04,  1.20989740e+02,  1.24009484e+02,  6.72801207e+03,
#         1.13013944e+02,  1.20990709e+02,  3.69669977e+04,  3.60016349e+02,
#         3.54490122e+04,  1.16987034e+02,  1.13997373e+02,  3.16549888e+04,
#         1.36998319e+03,  1.20300958e+03,  3.69459899e+04,  1.28010131e+02,
#         5.93985935e+02,  3.69569861e+04,  2.88320075e+04,  4.01998497e+02,
#         3.69539998e+04,  4.57010860e+02,  1.24010181e+02,  3.62620004e+04,
#         3.28270106e+04,  1.20007601e+02,  1.43599343e+03,  3.61320159e+04,
#         1.16985275e+02,  3.41009361e+02,  4.32982130e+02,  1.24995064e+02,
#         1.22006398e+02,  3.61659885e+04,  2.88759930e+04,  2.04001683e+02,
#         1.22007748e+02,  3.63690059e+04,  3.59460003e+04,  3.68209968e+04,
#         3.64440094e+04,  4.06898783e+03,  1.86997527e+02,  1.53298915e+03,
#         3.62960071e+04,  9.59799761e+03,  3.57160022e+04,  3.84401078e+03,
#         6.29903085e+01,  1.32101100e+03,  3.55070126e+04,  1.20991502e+02,
#         1.76798423e-04,  1.22500043e+03,  3.69669997e+04,  2.72900507e+03,
#         3.19850032e+04,  1.28011665e+02,  3.56996710e+02,  2.51590115e+04,
#         3.28996444e+02,  3.69914380e+01,  3.69669984e+04,  6.01012262e+02,
#         4.74014086e+02,  1.63198649e+03,  3.66279888e+04,  3.59599833e+04,
#         1.02999143e+03,  2.59350080e+04,  1.22280062e+04,  3.17810026e+04,
#         1.30801206e+03,  5.49700605e+03,  4.62984086e+02,  3.13689906e+04,
#         4.40799727e+03, -3.20068885e-04,  3.55899886e+04,  1.10000564e+03,
#         1.28011671e+02,  6.31352055e-04,  3.67529836e+04, -9.74189518e-04])

# %% [markdown]
# Making table for actual value and the predicted value

# %%
table = list(zip(y_test,y_pred))
regressor_diff = pd.DataFrame(table, columns = ['Actual Values', 'Predicted Values'] )
regressor_diff
# Out:
#      Actual Values  Predicted Values
# 0           4944.0       4943.983131
# 1            128.0        128.013549
# 2              0.0          0.000138
# 3          36387.0      36386.993633
# 4          10961.0      10960.990762
# ..             ...               ...
# 239         1100.0       1100.005642
# 240          128.0        128.011671
# 241            0.0          0.000631
# 242        36753.0      36752.983585
# 243            0.0         -0.000974
#
# [244 rows x 2 columns]

# %%
import statsmodels.formula.api as sm
result = sm.ols("total_deaths~population+total_cases+new_cases+new_cases_smoothed+total_cases_per_million+new_cases_per_million+new_cases_smoothed_per_million+total_deaths_per_million+reproduction_rate", data=CovidDeathsClean3).fit()

#print result.summary()
print (round(result.rsquared,4), round(result.rsquared_adj,4)) # If you're developing MLR, take rsquared_adj.
# Out:
# 1.0 1.0

# %%
import sklearn.metrics as metrics

mae = metrics.mean_absolute_error(y_test, y_pred)
mse = metrics.mean_squared_error(y_test, y_pred)
r2 = np.sqrt(metrics.mean_squared_error(y_test, y_pred))

print('Mean Absolute Error:', mae)
print('Mean Square Error:', mse)
print('Root Mean Square Error:', r2)
# Out:
# Mean Absolute Error: 0.007879735163181642
# Mean Square Error: 8.754462444163193e-05
# Root Mean Square Error: 0.00935652843963144

# %%
regressor_diff.to_csv ('regressor_diff.csv', index=None)
regressor_diff = pd.read_csv('regressor_diff.csv')
